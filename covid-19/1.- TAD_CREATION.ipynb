# %%
"""Importamos las librerias"""
import pandas as pd
import os
import numpy as np
import matplotlib as plt

# %%
os.listdir() #Checamos la dirección donde estan mis archivos
# Out:
# ['practicam1',
#  'EDA_UCI_POS.png',
#  'Enfermedades en pacientes registrados.jpg',
#  'Contagios por Covid 19 Febrero 2022 CDMX.jpg',
#  'datos_abiertos_covid19.zip',
#  'Pacientes Hospitalizados Covid 19 Historico CDMX.jpg',
#  ' EntregaProyecto_Arredondo_GInda_JesusAntonio.pdf',
#  'EDA_POSITIVO_REG.png',
#  'Muertos Covid 19 Historico CDMX.jpg',
#  'EDA_EDO_POS.png',
#  '.DS_Store',
#  'EDA_UCI.png',
#  'Muertos por Covid 19 Febrero 2022 EDOMEX.jpg',
#  'Modulo 2',
#  'EDA_MUESTRA_ANT_POS.png',
#  'Muertos en CDMX y EDOMEX los ultimos 4 meses.png',
#  'Serie muertes.jpg',
#  'Box_plot_edades_zcore.jpg',
#  'newplot.png',
#  'Enfermedades en pacientes registrados_hist.jpg',
#  'diccionario_datos_covid19',
#  'Muertos por Covid 19 Febrero 2022 CDMX.jpg',
#  'Estado en pacientes registrados.jpg',
#  'EDA_Proyecto_Arredondo_GInda_JesusAntonio.ipynb',
#  'EDA_CONTAGIOS_SERIE.png',
#  'CodigoProyecto_Arredondo_GInda_JesusAntonio.ipynb',
#  'EDA_ORIGEN.png',
# ...

# %%
path = os.getcwd()
path
# Out:
# '/Users/jesusarredondo/Documents/Diplomado/Proyecto'

# %%
"""Importamos nuestra data"""
path_data = os.getcwd()+"/220305COVID19MEXICO.csv"

# %%
df_covid = pd.read_csv(path_data,low_memory = False)
df_covid.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-03-05      z3bf80       2      12           8     2
# 1          2022-03-05      z1e370       1      12          14     1
# 2          2022-03-05      zze974       1       6          24     1
# 3          2022-03-05      zz7067       1      12           9     2
# 4          2022-03-05      z1da1e       1      12           1     2
# 5          2022-03-05      z393a3       1      12           9     1
# 6          2022-03-05      z59dea       1      12           7     2
# 7          2022-03-05      z5ba5b       2      12           8     2
# 8          2022-03-05      z2eace       1       3          15     1
# 9          2022-03-05      z38de4       1      12           7     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0            8            8             37              1  ...         2
# ...

# %%
df_covid.info() #Vemos el tipo de variables que tiene
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15225057 entries, 0 to 15225056
# Data columns (total 40 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   FECHA_ACTUALIZACION    object
#  1   ID_REGISTRO            object
#  2   ORIGEN                 int64
#  3   SECTOR                 int64
#  4   ENTIDAD_UM             int64
#  5   SEXO                   int64
#  6   ENTIDAD_NAC            int64
#  7   ENTIDAD_RES            int64
#  8   MUNICIPIO_RES          int64
#  9   TIPO_PACIENTE          int64
#  10  FECHA_INGRESO          object
#  11  FECHA_SINTOMAS         object
#  12  FECHA_DEF              object
#  13  INTUBADO               int64
#  14  NEUMONIA               int64
#  15  EDAD                   int64
#  16  NACIONALIDAD           int64
#  17  EMBARAZO               int64
#  18  HABLA_LENGUA_INDIG     int64
#  19  INDIGENA               int64
#  20  DIABETES               int64
#  21  EPOC                   int64
# ...

# %%
df_covid.dtypes
# Out:
# FECHA_ACTUALIZACION      object
# ID_REGISTRO              object
# ORIGEN                    int64
# SECTOR                    int64
# ENTIDAD_UM                int64
# SEXO                      int64
# ENTIDAD_NAC               int64
# ENTIDAD_RES               int64
# MUNICIPIO_RES             int64
# TIPO_PACIENTE             int64
# FECHA_INGRESO            object
# FECHA_SINTOMAS           object
# FECHA_DEF                object
# INTUBADO                  int64
# NEUMONIA                  int64
# EDAD                      int64
# NACIONALIDAD              int64
# EMBARAZO                  int64
# HABLA_LENGUA_INDIG        int64
# INDIGENA                  int64
# DIABETES                  int64
# EPOC                      int64
# ASMA                      int64
# INMUSUPR                  int64
# HIPERTENSION              int64
# OTRA_COM                  int64
# CARDIOVASCULAR            int64
# OBESIDAD                  int64
# RENAL_CRONICA             int64
# ...

# %%
df_covid.shape #Vemos la dimension de archivo inicial
# Out:
# (15225057, 40)

# %%
tipos = pd.DataFrame(df_covid.dtypes,columns= ["Tipos"])
tipos.value_counts() #Contamos el tipo de variables que se tienen
# Out:
# Tipos
# int64     33
# object     7
# dtype: int64

# %%
df_covid.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
df_covid["MUNICIPIO_RES"].head() #Vemos que los municipios de residencia son numeros que se mapean en un catalogo
# Out:
# 0    37
# 1    85
# 2    35
# 3     7
# 4     1
# Name: MUNICIPIO_RES, dtype: int64

# %%
df_covid["FECHA_ACTUALIZACION"].unique() #Vemos que la fecha de actualizacion es la misma para todos por lo cual no importa
# Out:
# array(['2022-03-05'], dtype=object)

# %%
fechas = list(df_covid["FECHA_INGRESO"].unique()) #Veamos el catalogo de fechas de ingreso

# %%
fechas.sort()

# %%
fechas[0] #Primer registro de fecha
# Out:
# '2020-01-01'

# %%
fechas[-1] #Ultimo registro
# Out:
# '2022-03-05'

# %%
df_covid["ENTIDAD_RES"].value_counts(dropna=False) #Entidad de residencia con mayor poblacion
# Out:
# 9     4850833
# 15    1607418
# 19     681396
# 11     657935
# 27     537401
# 14     510588
# 24     488494
# 5      378450
# 21     371648
# 30     347564
# 2      334906
# 26     329756
# 28     320877
# 16     309094
# 17     305643
# 22     278734
# 3      264805
# 25     261239
# 31     255656
# 8      232991
# 12     218826
# 20     203786
# 23     189376
# 1      183026
# 13     181411
# 7      181189
# 10     164398
# 32     143100
# 29     117945
# 18     115802
# 6      108115
# 4       92655
# Name: ENTIDAD_RES, dtype: int64

# %%
df_covid["ENTIDAD_RES"].value_counts(dropna=False)[9]+df_covid["ENTIDAD_RES"].value_counts(dropna=False)[15]
# Out:
# 6458251

# %%
df_cdmx = df_covid.loc[(df_covid["ENTIDAD_RES"]==9)] #Separamos a la cdmx que es la numero 1

# %%
df_edomex = df_covid.loc[(df_covid["ENTIDAD_RES"]==15)] #Separamos a edomex que es el numero 2

# %%
df_cdmx.shape[0]+df_edomex.shape[0]==df_covid["ENTIDAD_RES"].value_counts(dropna=False)[9]+df_covid["ENTIDAD_RES"].value_counts(dropna=False)[15]
# Out:
# True

# %%
df_cdmx.to_csv(path+"/COVID19CDMX.csv",index=False,encoding = "utf-8")
df_edomex.to_csv(path+"/COVID19EDOMEX.csv",index=False,encoding="utf-8")

# %%
df_cdmx.head(3)
# Out:
#    FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 3           2022-03-05      zz7067       1      12           9     2
# 5           2022-03-05      z393a3       1      12           9     1
# 19          2022-03-05      z12d63       2      12           9     2
#
#     ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 3             9            9              7              1  ...         2
# 5             9            9             17              1  ...         1
# 19            9            9             17              1  ...         2
#
#    TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 3                 1             2                      2                  97
# 5                 2            97                      1                   2
# 19                2            97                      2                  97
#
#     CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# ...

# %%
df_edomex.head(3)
# Out:
#    FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 8           2022-03-05      z2eace       1       3          15     1
# 10          2022-03-05      z579ac       1      12          15     2
# 24          2022-03-05      z4e838       1      12           9     2
#
#     ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 8            15           15            106              2  ...         2
# 10           15           15             60              1  ...         2
# 24           15           15             95              2  ...        99
#
#    TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 8                 1             4                      2                  97
# 10                1             4                      2                  97
# 24                1             2                      2                  97
#
#     CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# ...

# %%
df_cdmx.columns==df_edomex.columns #Comprobamos que las columnas sean las mismas
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
list(df_cdmx.columns)==list(df_covid.columns)
# Out:
# True

# %%
"""Importamos el catalogo a mapear en formato Json"""
import json
with open('/Users/jesusarredondo/Documents/Diplomado/Proyecto/diccionario_datos_covid19/201128 Catalogos.json')\
    as json_file: 
    data_json = json.load(json_file)

# %%
data_json["Catálogo ORIGEN"][0]["CLAVE"]
# Out:
# 1

# %%
"""Creamos los diccionarios"""
#Catalogo origen
catalogo_origen=dict()
llave = list(data_json["Catálogo ORIGEN"][0].keys())
for v in range(len(data_json["Catálogo ORIGEN"])):
    catalogo_origen.update({data_json["Catálogo ORIGEN"][v][llave[0]]:data_json["Catálogo ORIGEN"][v][llave[1]]})
catalogo_origen
# Out:
# {1: 'USMER', 2: 'FUERA DE USMER', 99: 'NO ESPECIFICADO'}

# %%
#Catalogo sector
data_json["Catálogo SECTOR"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'CRUZ ROJA'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'DIF'},
#  {'CLAVE': 3, 'DESCRIPCIÓN': 'ESTATAL'},
#  {'CLAVE': 4, 'DESCRIPCIÓN': 'IMSS'},
#  {'CLAVE': 5, 'DESCRIPCIÓN': 'IMSS-BIENESTAR'},
#  {'CLAVE': 6, 'DESCRIPCIÓN': 'ISSSTE'},
#  {'CLAVE': 7, 'DESCRIPCIÓN': 'MUNICIPAL'},
#  {'CLAVE': 8, 'DESCRIPCIÓN': 'PEMEX'},
#  {'CLAVE': 9, 'DESCRIPCIÓN': 'PRIVADA'},
#  {'CLAVE': 10, 'DESCRIPCIÓN': 'SEDENA'},
#  {'CLAVE': 11, 'DESCRIPCIÓN': 'SEMAR'},
#  {'CLAVE': 12, 'DESCRIPCIÓN': 'SSA'},
#  {'CLAVE': 13, 'DESCRIPCIÓN': 'UNIVERSITARIO'},
#  {'CLAVE': 99, 'DESCRIPCIÓN': 'NO ESPECIFICADO'}]

# %%
catalogo_sector=dict()
llave = list(data_json["Catálogo SECTOR"][0].keys())
for v in range(len(data_json["Catálogo SECTOR"])):
    catalogo_sector.update({data_json["Catálogo SECTOR"][v][llave[0]]:data_json["Catálogo SECTOR"][v][llave[1]]})
catalogo_sector
# Out:
# {1: 'CRUZ ROJA',
#  2: 'DIF',
#  3: 'ESTATAL',
#  4: 'IMSS',
#  5: 'IMSS-BIENESTAR',
#  6: 'ISSSTE',
#  7: 'MUNICIPAL',
#  8: 'PEMEX',
#  9: 'PRIVADA',
#  10: 'SEDENA',
#  11: 'SEMAR',
#  12: 'SSA',
#  13: 'UNIVERSITARIO',
#  99: 'NO ESPECIFICADO'}

# %%
#Catálogo SEXO
data_json["Catálogo SEXO"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'MUJER'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'HOMBRE'},
#  {'CLAVE': 99, 'DESCRIPCIÓN': 'NO ESPECIFICADO'}]

# %%
catalogo_sexo = dict()
llave = list(data_json["Catálogo SEXO"][0].keys())
for v in range(len(data_json["Catálogo SEXO"])):
    catalogo_sexo.update({data_json["Catálogo SEXO"][v][llave[0]]:data_json["Catálogo SEXO"][v][llave[1]]})
catalogo_sexo
# Out:
# {1: 'MUJER', 2: 'HOMBRE', 99: 'NO ESPECIFICADO'}

# %%
#Catálogo TIPO_PACIENTE
data_json["Catálogo TIPO_PACIENTE"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'AMBULATORIO'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'HOSPITALIZADO'},
#  {'CLAVE': 99, 'DESCRIPCIÓN': 'NO ESPECIFICADO'}]

# %%
catalogo_tipo_paciente = dict()
llave = list(data_json["Catálogo TIPO_PACIENTE"][0].keys())
for v in range(len(data_json["Catálogo TIPO_PACIENTE"])):
    catalogo_tipo_paciente.update({data_json["Catálogo TIPO_PACIENTE"][v][llave[0]]:data_json["Catálogo TIPO_PACIENTE"][v][llave[1]]})
catalogo_tipo_paciente
# Out:
# {1: 'AMBULATORIO', 2: 'HOSPITALIZADO', 99: 'NO ESPECIFICADO'}

# %%
#Catálogo SI_NO
data_json["Catálogo SI_NO"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'SI '},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'NO '},
#  {'CLAVE': 97, 'DESCRIPCIÓN': 'NO APLICA'},
#  {'CLAVE': 98, 'DESCRIPCIÓN': 'SE IGNORA'},
#  {'CLAVE': 99, 'DESCRIPCIÓN': 'NO ESPECIFICADO'}]

# %%
catalogo_si_no = dict()
llave = list(data_json["Catálogo SI_NO"][0].keys())
for v in range(len(data_json["Catálogo SI_NO"])):
    catalogo_si_no.update({data_json["Catálogo SI_NO"][v][llave[0]]:data_json["Catálogo SI_NO"][v][llave[1]]})
catalogo_si_no
# Out:
# {1: 'SI ', 2: 'NO ', 97: 'NO APLICA', 98: 'SE IGNORA', 99: 'NO ESPECIFICADO'}

# %%
#Catálogo NACIONALIDAD
data_json["Catálogo NACIONALIDAD"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'MEXICANA'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'EXTRANJERA'},
#  {'CLAVE': 99, 'DESCRIPCIÓN': 'NO ESPECIFICADO'}]

# %%
catalogo_nacionalidad = dict()
llave = list(data_json["Catálogo NACIONALIDAD"][0].keys())
for v in range(len(data_json["Catálogo NACIONALIDAD"])):
    catalogo_nacionalidad.update({data_json["Catálogo NACIONALIDAD"][v][llave[0]]:data_json["Catálogo NACIONALIDAD"][v][llave[1]]})
catalogo_nacionalidad
# Out:
# {1: 'MEXICANA', 2: 'EXTRANJERA', 99: 'NO ESPECIFICADO'}

# %%
#Catálogo RESULTADO_LAB
data_json["Catálogo RESULTADO_LAB"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'POSITIVO A SARS-COV-2'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'NO POSITIVO A SARS-COV-2'},
#  {'CLAVE': 3, 'DESCRIPCIÓN': 'RESULTADO PENDIENTE'},
#  {'CLAVE': 4, 'DESCRIPCIÓN': 'RESULTADO NO ADECUADO '},
#  {'CLAVE': 97, 'DESCRIPCIÓN': 'NO APLICA (CASO SIN MUESTRA)'}]

# %%
catalogo_resultado_lab = dict()
llave = list(data_json["Catálogo RESULTADO_LAB"][0].keys())
for v in range(len(data_json["Catálogo RESULTADO_LAB"])):
    catalogo_resultado_lab.update({data_json["Catálogo RESULTADO_LAB"][v][llave[0]]:data_json["Catálogo RESULTADO_LAB"][v][llave[1]]})
catalogo_resultado_lab
# Out:
# {1: 'POSITIVO A SARS-COV-2',
#  2: 'NO POSITIVO A SARS-COV-2',
#  3: 'RESULTADO PENDIENTE',
#  4: 'RESULTADO NO ADECUADO ',
#  97: 'NO APLICA (CASO SIN MUESTRA)'}

# %%
#Catálogo RESULTADO_ANTIGENO
data_json["Catálogo RESULTADO_ANTIGENO"]
# Out:
# [{'CLAVE': 1, 'DESCRIPCIÓN': 'POSITIVO A SARS-COV-2'},
#  {'CLAVE': 2, 'DESCRIPCIÓN': 'NEGATIVO A SARS-COV-2'},
#  {'CLAVE': 97, 'DESCRIPCIÓN': 'NO APLICA (CASO SIN MUESTRA)'}]

# %%
catalogo_resultado_antigeno = dict()
llave = list(data_json["Catálogo RESULTADO_ANTIGENO"][0].keys())
for v in range(len(data_json["Catálogo RESULTADO_ANTIGENO"])):
    catalogo_resultado_antigeno.update({data_json["Catálogo RESULTADO_ANTIGENO"][v][llave[0]]:data_json["Catálogo RESULTADO_ANTIGENO"][v][llave[1]]})
catalogo_resultado_antigeno
# Out:
# {1: 'POSITIVO A SARS-COV-2',
#  2: 'NEGATIVO A SARS-COV-2',
#  97: 'NO APLICA (CASO SIN MUESTRA)'}

# %%
#Catálogo CLASIFICACION_FINAL
data_json["Catálogo CLASIFICACION_FINAL"]
# Out:
# [{'CLAVE': 1,
#   'CLASIFICACIÓN': 'CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA',
#   'DESCRIPCIÓN': 'Confirmado por asociación aplica cuando el caso informó ser contacto de un positivo a COVID-19 (y este se encuentra registrado en el SISVER) y:\nAl caso no se le tomo muestra o la muestra resultó no válida. '},
#  {'CLAVE': 2,
#   'CLASIFICACIÓN': 'CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN',
#   'DESCRIPCIÓN': 'Confirmado por dictaminación solo aplica para defunciones bajo las siguientes condiciones: \nAl caso no se le tomo muestra o sí se tomó muestra, pero la muestra resultó no válida. '},
#  {'CLAVE': 3,
#   'CLASIFICACIÓN': 'CASO DE SARS-COV-2  CONFIRMADO',
#   'DESCRIPCIÓN': 'Confirmado aplica cuando:\nEl caso tiene muestra de laboratorio o prueba antigénica y resultó positiva  a SARS-CoV-2, sin importar si el caso tienen asociación clínica epidemiológica.'},
#  {'CLAVE': 4,
#   'CLASIFICACIÓN': 'INVÁLIDO POR LABORATORIO',
# ...

# %%
catalogo_clasificacion_final = dict()
llave = list(data_json["Catálogo CLASIFICACION_FINAL"][0].keys())
for v in range(len(data_json["Catálogo CLASIFICACION_FINAL"])):
    catalogo_clasificacion_final.update({data_json["Catálogo CLASIFICACION_FINAL"][v][llave[0]]:data_json["Catálogo CLASIFICACION_FINAL"][v][llave[1]]})
catalogo_clasificacion_final
# Out:
# {1: 'CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA',
#  2: 'CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN',
#  3: 'CASO DE SARS-COV-2  CONFIRMADO',
#  4: 'INVÁLIDO POR LABORATORIO',
#  5: 'NO REALIZADO POR LABORATORIO',
#  6: 'CASO SOSPECHOSO',
#  7: 'NEGATIVO A SARS-COV-2'}

# %%
#Catálogo ENTIDADES
data_json["Catálogo de ENTIDADES"]
# Out:
# [{'CLAVE_ENTIDAD': '01',
#   'ENTIDAD_FEDERATIVA': 'AGUASCALIENTES',
#   'ABREVIATURA': 'AS'},
#  {'CLAVE_ENTIDAD': '02',
#   'ENTIDAD_FEDERATIVA': 'BAJA CALIFORNIA',
#   'ABREVIATURA': 'BC'},
#  {'CLAVE_ENTIDAD': '03',
#   'ENTIDAD_FEDERATIVA': 'BAJA CALIFORNIA SUR',
#   'ABREVIATURA': 'BS'},
#  {'CLAVE_ENTIDAD': '04',
#   'ENTIDAD_FEDERATIVA': 'CAMPECHE',
#   'ABREVIATURA': 'CC'},
#  {'CLAVE_ENTIDAD': '05',
#   'ENTIDAD_FEDERATIVA': 'COAHUILA DE ZARAGOZA',
#   'ABREVIATURA': 'CL'},
#  {'CLAVE_ENTIDAD': '06', 'ENTIDAD_FEDERATIVA': 'COLIMA', 'ABREVIATURA': 'CM'},
#  {'CLAVE_ENTIDAD': '07', 'ENTIDAD_FEDERATIVA': 'CHIAPAS', 'ABREVIATURA': 'CS'},
#  {'CLAVE_ENTIDAD': '08',
#   'ENTIDAD_FEDERATIVA': 'CHIHUAHUA',
#   'ABREVIATURA': 'CH'},
#  {'CLAVE_ENTIDAD': '09',
#   'ENTIDAD_FEDERATIVA': 'CIUDAD DE MÉXICO',
#   'ABREVIATURA': 'DF'},
#  {'CLAVE_ENTIDAD': '10', 'ENTIDAD_FEDERATIVA': 'DURANGO', 'ABREVIATURA': 'DG'},
#  {'CLAVE_ENTIDAD': '11',
#   'ENTIDAD_FEDERATIVA': 'GUANAJUATO',
# ...

# %%
catalogo_entidades = dict()
llave = list(data_json["Catálogo de ENTIDADES"][0].keys())
for v in range(len(data_json["Catálogo de ENTIDADES"])):
    catalogo_entidades.update({int(data_json["Catálogo de ENTIDADES"][v][llave[0]]):data_json["Catálogo de ENTIDADES"][v][llave[1]]})
catalogo_entidades
# Out:
# {1: 'AGUASCALIENTES',
#  2: 'BAJA CALIFORNIA',
#  3: 'BAJA CALIFORNIA SUR',
#  4: 'CAMPECHE',
#  5: 'COAHUILA DE ZARAGOZA',
#  6: 'COLIMA',
#  7: 'CHIAPAS',
#  8: 'CHIHUAHUA',
#  9: 'CIUDAD DE MÉXICO',
#  10: 'DURANGO',
#  11: 'GUANAJUATO',
#  12: 'GUERRERO',
#  13: 'HIDALGO',
#  14: 'JALISCO',
#  15: 'MÉXICO',
#  16: 'MICHOACÁN DE OCAMPO',
#  17: 'MORELOS',
#  18: 'NAYARIT',
#  19: 'NUEVO LEÓN',
#  20: 'OAXACA',
#  21: 'PUEBLA',
#  22: 'QUERÉTARO',
#  23: 'QUINTANA ROO',
#  24: 'SAN LUIS POTOSÍ',
#  25: 'SINALOA',
#  26: 'SONORA',
#  27: 'TABASCO',
#  28: 'TAMAULIPAS',
#  29: 'TLAXCALA',
#  30: 'VERACRUZ DE IGNACIO DE LA LLAVE',
#  31: 'YUCATÁN',
#  32: 'ZACATECAS',
#  36: 'ESTADOS UNIDOS MEXICANOS',
#  97: 'NO APLICA',
#  98: 'SE IGNORA',
#  99: 'NO ESPECIFICADO'}

# %%
#Catálogo MUNICIPIOS
data_json["Catálogo MUNICIPIOS"]
# Out:
# [{'CLAVE_MUNICIPIO': '001',
#   'MUNICIPIO': 'AGUASCALIENTES',
#   'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '002', 'MUNICIPIO': 'ASIENTOS', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '003', 'MUNICIPIO': 'CALVILLO', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '004', 'MUNICIPIO': 'COSÍO', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '005', 'MUNICIPIO': 'JESÚS MARÍA', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '006',
#   'MUNICIPIO': 'PABELLÓN DE ARTEAGA',
#   'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '007',
#   'MUNICIPIO': 'RINCÓN DE ROMOS',
#   'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '008',
#   'MUNICIPIO': 'SAN JOSÉ DE GRACIA',
#   'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '009', 'MUNICIPIO': 'TEPEZALÁ', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '010', 'MUNICIPIO': 'EL LLANO', 'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '011',
#   'MUNICIPIO': 'SAN FRANCISCO DE LOS ROMO',
#   'CLAVE_ENTIDAD': '01'},
#  {'CLAVE_MUNICIPIO': '999',
# ...

# %%
"""Dado que operar con este json es complejo vamos a operarlo como df"""
df_catalogo_municipio= pd.read_excel("/Users/jesusarredondo/Documents/Diplomado/Proyecto/diccionario_datos_covid19/201128 Catalogos.xlsx",sheet_name="Catálogo MUNICIPIOS")

# %%
df_catalogo_municipio
# Out:
#       CLAVE_MUNICIPIO        MUNICIPIO  CLAVE_ENTIDAD
# 0                   1   AGUASCALIENTES              1
# 1                   2         ASIENTOS              1
# 2                   3         CALVILLO              1
# 3                   4            COSÍO              1
# 4                   5      JESÚS MARÍA              1
# ...               ...              ...            ...
# 2496              999  NO ESPECIFICADO             32
# 2497              999  NO ESPECIFICADO             36
# 2498              997        NO APLICA             97
# 2499              998        SE IGNORA             98
# 2500              999  NO ESPECIFICADO             99
#
# [2501 rows x 3 columns]

# %%
df_catalogo_municipio.loc[df_catalogo_municipio["CLAVE_ENTIDAD"]==9]
# Out:
#      CLAVE_MUNICIPIO               MUNICIPIO  CLAVE_ENTIDAD
# 278                2            AZCAPOTZALCO              9
# 279                3                COYOACÁN              9
# 280                4   CUAJIMALPA DE MORELOS              9
# 281                5       GUSTAVO A. MADERO              9
# 282                6               IZTACALCO              9
# 283                7              IZTAPALAPA              9
# 284                8  LA MAGDALENA CONTRERAS              9
# 285                9              MILPA ALTA              9
# 286               10          ÁLVARO OBREGÓN              9
# 287               11                 TLÁHUAC              9
# 288               12                 TLALPAN              9
# 289               13              XOCHIMILCO              9
# 290               14           BENITO JUÁREZ              9
# 291               15              CUAUHTÉMOC              9
# 292               16          MIGUEL HIDALGO              9
# ...

# %%
"""Catalogo Municipios CDMX"""
catalogo_municipios_cdmx=dict()
catalogo_municipios_cdmx.update(dict(df_catalogo_municipio.loc[df_catalogo_municipio["CLAVE_ENTIDAD"]==9][["CLAVE_MUNICIPIO","MUNICIPIO"]].values))

# %%
catalogo_municipios_cdmx
# Out:
# {2: 'AZCAPOTZALCO',
#  3: 'COYOACÁN',
#  4: 'CUAJIMALPA DE MORELOS',
#  5: 'GUSTAVO A. MADERO',
#  6: 'IZTACALCO',
#  7: 'IZTAPALAPA',
#  8: 'LA MAGDALENA CONTRERAS',
#  9: 'MILPA ALTA',
#  10: 'ÁLVARO OBREGÓN',
#  11: 'TLÁHUAC',
#  12: 'TLALPAN',
#  13: 'XOCHIMILCO',
#  14: 'BENITO JUÁREZ',
#  15: 'CUAUHTÉMOC',
#  16: 'MIGUEL HIDALGO',
#  17: 'VENUSTIANO CARRANZA',
#  999: 'NO ESPECIFICADO'}

# %%
"""Catalogo Municipios EDOMEX"""
catalogo_municipios_edomex=dict()
catalogo_municipios_edomex.update(dict(df_catalogo_municipio.loc[df_catalogo_municipio["CLAVE_ENTIDAD"]==15][["CLAVE_MUNICIPIO","MUNICIPIO"]].values))

# %%
catalogo_municipios_edomex
# Out:
# {1: 'ACAMBAY DE RUÍZ CASTAÑEDA',
#  2: 'ACOLMAN',
#  3: 'ACULCO',
#  4: 'ALMOLOYA DE ALQUISIRAS',
#  5: 'ALMOLOYA DE JUÁREZ',
#  6: 'ALMOLOYA DEL RÍO',
#  7: 'AMANALCO',
#  8: 'AMATEPEC',
#  9: 'AMECAMECA',
#  10: 'APAXCO',
#  11: 'ATENCO',
#  12: 'ATIZAPÁN',
#  13: 'ATIZAPÁN DE ZARAGOZA',
#  14: 'ATLACOMULCO',
#  15: 'ATLAUTLA',
#  16: 'AXAPUSCO',
#  17: 'AYAPANGO',
#  18: 'CALIMAYA',
#  19: 'CAPULHUAC',
#  20: 'COACALCO DE BERRIOZÁBAL',
#  21: 'COATEPEC HARINAS',
#  22: 'COCOTITLÁN',
#  23: 'COYOTEPEC',
#  24: 'CUAUTITLÁN',
#  25: 'CHALCO',
#  26: 'CHAPA DE MOTA',
#  27: 'CHAPULTEPEC',
#  28: 'CHIAUTLA',
#  29: 'CHICOLOAPAN',
#  30: 'CHICONCUAC',
#  31: 'CHIMALHUACÁN',
#  32: 'DONATO GUERRA',
#  33: 'ECATEPEC DE MORELOS',
#  34: 'ECATZINGO',
#  35: 'HUEHUETOCA',
#  36: 'HUEYPOXTLA',
#  37: 'HUIXQUILUCAN',
#  38: 'ISIDRO FABELA',
#  39: 'IXTAPALUCA',
#  40: 'IXTAPAN DE LA SAL',
#  41: 'IXTAPAN DEL ORO',
#  42: 'IXTLAHUACA',
#  43: 'XALATLACO',
#  44: 'JALTENCO',
#  45: 'JILOTEPEC',
# ...

# %%
"""Eliminamos los datos que no vamos a usar ya"""
del(df_catalogo_municipio)
del(data_json)

# %% [markdown]
# ## Catalogos a mapear

# %%
"""Agrupamos todos los catalogos creados"""
catalogo_origen
# Out:
# {1: 'USMER', 2: 'FUERA DE USMER', 99: 'NO ESPECIFICADO'}

# %%
catalogo_sector
# Out:
# {1: 'CRUZ ROJA',
#  2: 'DIF',
#  3: 'ESTATAL',
#  4: 'IMSS',
#  5: 'IMSS-BIENESTAR',
#  6: 'ISSSTE',
#  7: 'MUNICIPAL',
#  8: 'PEMEX',
#  9: 'PRIVADA',
#  10: 'SEDENA',
#  11: 'SEMAR',
#  12: 'SSA',
#  13: 'UNIVERSITARIO',
#  99: 'NO ESPECIFICADO'}

# %%
catalogo_sexo
# Out:
# {1: 'MUJER', 2: 'HOMBRE', 99: 'NO ESPECIFICADO'}

# %%
catalogo_tipo_paciente
# Out:
# {1: 'AMBULATORIO', 2: 'HOSPITALIZADO', 99: 'NO ESPECIFICADO'}

# %%
catalogo_si_no
# Out:
# {1: 'SI ', 2: 'NO ', 97: 'NO APLICA', 98: 'SE IGNORA', 99: 'NO ESPECIFICADO'}

# %%
catalogo_nacionalidad
# Out:
# {1: 'MEXICANA', 2: 'EXTRANJERA', 99: 'NO ESPECIFICADO'}

# %%
catalogo_resultado_lab
# Out:
# {1: 'POSITIVO A SARS-COV-2',
#  2: 'NO POSITIVO A SARS-COV-2',
#  3: 'RESULTADO PENDIENTE',
#  4: 'RESULTADO NO ADECUADO ',
#  97: 'NO APLICA (CASO SIN MUESTRA)'}

# %%
catalogo_resultado_antigeno
# Out:
# {1: 'POSITIVO A SARS-COV-2',
#  2: 'NEGATIVO A SARS-COV-2',
#  97: 'NO APLICA (CASO SIN MUESTRA)'}

# %%
catalogo_clasificacion_final
# Out:
# {1: 'CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA',
#  2: 'CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN',
#  3: 'CASO DE SARS-COV-2  CONFIRMADO',
#  4: 'INVÁLIDO POR LABORATORIO',
#  5: 'NO REALIZADO POR LABORATORIO',
#  6: 'CASO SOSPECHOSO',
#  7: 'NEGATIVO A SARS-COV-2'}

# %%
catalogo_entidades
# Out:
# {1: 'AGUASCALIENTES',
#  2: 'BAJA CALIFORNIA',
#  3: 'BAJA CALIFORNIA SUR',
#  4: 'CAMPECHE',
#  5: 'COAHUILA DE ZARAGOZA',
#  6: 'COLIMA',
#  7: 'CHIAPAS',
#  8: 'CHIHUAHUA',
#  9: 'CIUDAD DE MÉXICO',
#  10: 'DURANGO',
#  11: 'GUANAJUATO',
#  12: 'GUERRERO',
#  13: 'HIDALGO',
#  14: 'JALISCO',
#  15: 'MÉXICO',
#  16: 'MICHOACÁN DE OCAMPO',
#  17: 'MORELOS',
#  18: 'NAYARIT',
#  19: 'NUEVO LEÓN',
#  20: 'OAXACA',
#  21: 'PUEBLA',
#  22: 'QUERÉTARO',
#  23: 'QUINTANA ROO',
#  24: 'SAN LUIS POTOSÍ',
#  25: 'SINALOA',
#  26: 'SONORA',
#  27: 'TABASCO',
#  28: 'TAMAULIPAS',
#  29: 'TLAXCALA',
#  30: 'VERACRUZ DE IGNACIO DE LA LLAVE',
#  31: 'YUCATÁN',
#  32: 'ZACATECAS',
#  36: 'ESTADOS UNIDOS MEXICANOS',
#  97: 'NO APLICA',
#  98: 'SE IGNORA',
#  99: 'NO ESPECIFICADO'}

# %%
catalogo_municipios_cdmx
# Out:
# {2: 'AZCAPOTZALCO',
#  3: 'COYOACÁN',
#  4: 'CUAJIMALPA DE MORELOS',
#  5: 'GUSTAVO A. MADERO',
#  6: 'IZTACALCO',
#  7: 'IZTAPALAPA',
#  8: 'LA MAGDALENA CONTRERAS',
#  9: 'MILPA ALTA',
#  10: 'ÁLVARO OBREGÓN',
#  11: 'TLÁHUAC',
#  12: 'TLALPAN',
#  13: 'XOCHIMILCO',
#  14: 'BENITO JUÁREZ',
#  15: 'CUAUHTÉMOC',
#  16: 'MIGUEL HIDALGO',
#  17: 'VENUSTIANO CARRANZA',
#  999: 'NO ESPECIFICADO'}

# %%
catalogo_municipios_edomex
# Out:
# {1: 'ACAMBAY DE RUÍZ CASTAÑEDA',
#  2: 'ACOLMAN',
#  3: 'ACULCO',
#  4: 'ALMOLOYA DE ALQUISIRAS',
#  5: 'ALMOLOYA DE JUÁREZ',
#  6: 'ALMOLOYA DEL RÍO',
#  7: 'AMANALCO',
#  8: 'AMATEPEC',
#  9: 'AMECAMECA',
#  10: 'APAXCO',
#  11: 'ATENCO',
#  12: 'ATIZAPÁN',
#  13: 'ATIZAPÁN DE ZARAGOZA',
#  14: 'ATLACOMULCO',
#  15: 'ATLAUTLA',
#  16: 'AXAPUSCO',
#  17: 'AYAPANGO',
#  18: 'CALIMAYA',
#  19: 'CAPULHUAC',
#  20: 'COACALCO DE BERRIOZÁBAL',
#  21: 'COATEPEC HARINAS',
#  22: 'COCOTITLÁN',
#  23: 'COYOTEPEC',
#  24: 'CUAUTITLÁN',
#  25: 'CHALCO',
#  26: 'CHAPA DE MOTA',
#  27: 'CHAPULTEPEC',
#  28: 'CHIAUTLA',
#  29: 'CHICOLOAPAN',
#  30: 'CHICONCUAC',
#  31: 'CHIMALHUACÁN',
#  32: 'DONATO GUERRA',
#  33: 'ECATEPEC DE MORELOS',
#  34: 'ECATZINGO',
#  35: 'HUEHUETOCA',
#  36: 'HUEYPOXTLA',
#  37: 'HUIXQUILUCAN',
#  38: 'ISIDRO FABELA',
#  39: 'IXTAPALUCA',
#  40: 'IXTAPAN DE LA SAL',
#  41: 'IXTAPAN DEL ORO',
#  42: 'IXTLAHUACA',
#  43: 'XALATLACO',
#  44: 'JALTENCO',
#  45: 'JILOTEPEC',
# ...

# %% [markdown]
# ## Mapeamos los datos en el data frame de la cdmx y edomex

# %%
df_cdmx=df_cdmx.reset_index(drop=True)
df_cdmx.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-03-05      zz7067       1      12           9     2
# 1          2022-03-05      z393a3       1      12           9     1
# 2          2022-03-05      z12d63       2      12           9     2
# 3          2022-03-05      z13788       1      12           9     1
# 4          2022-03-05      z2b144       2      12           9     1
# 5          2022-03-05      z526b3       2      12           9     1
# 6          2022-03-05      z3d1e2       2      12           9     1
# 7          2022-03-05      z29dac       2      12           9     1
# 8          2022-03-05      z45dcb       2      12           9     2
# 9          2022-03-05      z23c2e       2      12           9     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0            9            9              7              1  ...         2
# ...

# %%
df_edomex=df_edomex.reset_index(drop=True)
df_edomex.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-03-05      z2eace       1       3          15     1
# 1          2022-03-05      z579ac       1      12          15     2
# 2          2022-03-05      z4e838       1      12           9     2
# 3          2022-03-05      z1b053       2      12           9     2
# 4          2022-03-05      z454b5       1       6          15     1
# 5          2022-03-05      z39e04       1      12          15     1
# 6          2022-03-05      z58ebe       1       9           9     1
# 7          2022-03-05      z39c9e       1      12          15     2
# 8          2022-03-05      z4e4e4       1       6          15     2
# 9          2022-03-05      01c25f       1      12          17     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0           15           15            106              2  ...         2
# ...

# %%
"""Para cdmx"""
df_cdmx_=df_cdmx.copy()
df_cdmx_["ORIGEN"]=df_cdmx_["ORIGEN"].map(catalogo_origen)
df_cdmx_.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-03-05      zz7067           USMER      12           9     2
# 1          2022-03-05      z393a3           USMER      12           9     1
# 2          2022-03-05      z12d63  FUERA DE USMER      12           9     2
# 3          2022-03-05      z13788           USMER      12           9     1
# 4          2022-03-05      z2b144  FUERA DE USMER      12           9     1
# 5          2022-03-05      z526b3  FUERA DE USMER      12           9     1
# 6          2022-03-05      z3d1e2  FUERA DE USMER      12           9     1
# 7          2022-03-05      z29dac  FUERA DE USMER      12           9     1
# 8          2022-03-05      z45dcb  FUERA DE USMER      12           9     2
# 9          2022-03-05      z23c2e  FUERA DE USMER      12           9     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# ...

# %%
df_cdmx_["ORIGEN"].unique()
# Out:
# array(['USMER', 'FUERA DE USMER'], dtype=object)

# %%
df_cdmx.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
df_cdmx_["SECTOR"]=df_cdmx_["SECTOR"].map(catalogo_sector)
df_cdmx_["ENTIDAD_UM"]=df_cdmx_["ENTIDAD_UM"].map(catalogo_entidades)
df_cdmx_["SEXO"]=df_cdmx_["SEXO"].map(catalogo_sexo)
df_cdmx_["ENTIDAD_NAC"]=df_cdmx_["ENTIDAD_NAC"].map(catalogo_entidades)
df_cdmx_["ENTIDAD_RES"]=df_cdmx_["ENTIDAD_RES"].map(catalogo_entidades)
df_cdmx_["MUNICIPIO_RES"]=df_cdmx_["MUNICIPIO_RES"].map(catalogo_municipios_cdmx)
df_cdmx_["TIPO_PACIENTE"]=df_cdmx_["TIPO_PACIENTE"].map(catalogo_tipo_paciente)
df_cdmx_["INTUBADO"]=df_cdmx_["INTUBADO"].map(catalogo_si_no)
df_cdmx_["NEUMONIA"]=df_cdmx_["NEUMONIA"].map(catalogo_si_no)
df_cdmx_["NACIONALIDAD"]=df_cdmx_["NACIONALIDAD"].map(catalogo_nacionalidad)
df_cdmx_["EMBARAZO"]=df_cdmx_["EMBARAZO"].map(catalogo_si_no)
df_cdmx_["HABLA_LENGUA_INDIG"]=df_cdmx_["HABLA_LENGUA_INDIG"].map(catalogo_si_no)
df_cdmx_["INDIGENA"]=df_cdmx_["INDIGENA"].map(catalogo_si_no)
df_cdmx_["DIABETES"]=df_cdmx_["DIABETES"].map(catalogo_si_no)
df_cdmx_["EPOC"]=df_cdmx_["EPOC"].map(catalogo_si_no)
df_cdmx_["ASMA"]=df_cdmx_["ASMA"].map(catalogo_si_no)
df_cdmx_["INMUSUPR"]=df_cdmx_["INMUSUPR"].map(catalogo_si_no)
df_cdmx_["HIPERTENSION"]=df_cdmx_["HIPERTENSION"].map(catalogo_si_no)
df_cdmx_["OTRA_COM"]=df_cdmx_["OTRA_COM"].map(catalogo_si_no)
df_cdmx_["CARDIOVASCULAR"]=df_cdmx_["CARDIOVASCULAR"].map(catalogo_si_no)
df_cdmx_["OBESIDAD"]=df_cdmx_["OBESIDAD"].map(catalogo_si_no)
df_cdmx_["RENAL_CRONICA"]=df_cdmx_["RENAL_CRONICA"].map(catalogo_si_no)
df_cdmx_["TABAQUISMO"]=df_cdmx_["TABAQUISMO"].map(catalogo_si_no)
df_cdmx_["OTRO_CASO"]=df_cdmx_["OTRO_CASO"].map(catalogo_si_no)
df_cdmx_["TOMA_MUESTRA_LAB"]=df_cdmx_["TOMA_MUESTRA_LAB"].map(catalogo_si_no)
df_cdmx_["RESULTADO_LAB"]=df_cdmx_["RESULTADO_LAB"].map(catalogo_resultado_lab)
df_cdmx_["TOMA_MUESTRA_ANTIGENO"]=df_cdmx_["TOMA_MUESTRA_ANTIGENO"].map(catalogo_si_no)
df_cdmx_["RESULTADO_ANTIGENO"]=df_cdmx_["RESULTADO_ANTIGENO"].map(catalogo_resultado_antigeno)
df_cdmx_["CLASIFICACION_FINAL"]=df_cdmx_["CLASIFICACION_FINAL"].map(catalogo_clasificacion_final)
df_cdmx_["MIGRANTE"]=df_cdmx_["MIGRANTE"].map(catalogo_si_no)
df_cdmx_["UCI"]=df_cdmx_["UCI"].map(catalogo_si_no)

# %%
df_cdmx_.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 5          2022-03-05      z526b3  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 6          2022-03-05      z3d1e2  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 7          2022-03-05      z29dac  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 8          2022-03-05      z45dcb  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 9          2022-03-05      z23c2e  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# ...

# %%
df_edomex_=df_edomex.copy()

# %%
"""Para EDOMEX"""
df_edomex_["ORIGEN"]=df_edomex_["ORIGEN"].map(catalogo_origen)
df_edomex_["SECTOR"]=df_edomex_["SECTOR"].map(catalogo_sector)
df_edomex_["ENTIDAD_UM"]=df_edomex_["ENTIDAD_UM"].map(catalogo_entidades)
df_edomex_["SEXO"]=df_edomex_["SEXO"].map(catalogo_sexo)
df_edomex_["ENTIDAD_NAC"]=df_edomex_["ENTIDAD_NAC"].map(catalogo_entidades)
df_edomex_["ENTIDAD_RES"]=df_edomex_["ENTIDAD_RES"].map(catalogo_entidades)
df_edomex_["MUNICIPIO_RES"]=df_edomex_["MUNICIPIO_RES"].map(catalogo_municipios_edomex)
df_edomex_["TIPO_PACIENTE"]=df_edomex_["TIPO_PACIENTE"].map(catalogo_tipo_paciente)
df_edomex_["INTUBADO"]=df_edomex_["INTUBADO"].map(catalogo_si_no)
df_edomex_["NEUMONIA"]=df_edomex_["NEUMONIA"].map(catalogo_si_no)
df_edomex_["NACIONALIDAD"]=df_edomex_["NACIONALIDAD"].map(catalogo_nacionalidad)
df_edomex_["EMBARAZO"]=df_edomex_["EMBARAZO"].map(catalogo_si_no)
df_edomex_["HABLA_LENGUA_INDIG"]=df_edomex_["HABLA_LENGUA_INDIG"].map(catalogo_si_no)
df_edomex_["INDIGENA"]=df_edomex_["INDIGENA"].map(catalogo_si_no)
df_edomex_["DIABETES"]=df_edomex_["DIABETES"].map(catalogo_si_no)
df_edomex_["EPOC"]=df_edomex_["EPOC"].map(catalogo_si_no)
df_edomex_["ASMA"]=df_edomex_["ASMA"].map(catalogo_si_no)
df_edomex_["INMUSUPR"]=df_edomex_["INMUSUPR"].map(catalogo_si_no)
df_edomex_["HIPERTENSION"]=df_edomex_["HIPERTENSION"].map(catalogo_si_no)
df_edomex_["OTRA_COM"]=df_edomex_["OTRA_COM"].map(catalogo_si_no)
df_edomex_["CARDIOVASCULAR"]=df_edomex_["CARDIOVASCULAR"].map(catalogo_si_no)
df_edomex_["OBESIDAD"]=df_edomex_["OBESIDAD"].map(catalogo_si_no)
df_edomex_["RENAL_CRONICA"]=df_edomex_["RENAL_CRONICA"].map(catalogo_si_no)
df_edomex_["TABAQUISMO"]=df_edomex_["TABAQUISMO"].map(catalogo_si_no)
df_edomex_["OTRO_CASO"]=df_edomex_["OTRO_CASO"].map(catalogo_si_no)
df_edomex_["TOMA_MUESTRA_LAB"]=df_edomex_["TOMA_MUESTRA_LAB"].map(catalogo_si_no)
df_edomex_["RESULTADO_LAB"]=df_edomex_["RESULTADO_LAB"].map(catalogo_resultado_lab)
df_edomex_["TOMA_MUESTRA_ANTIGENO"]=df_edomex_["TOMA_MUESTRA_ANTIGENO"].map(catalogo_si_no)
df_edomex_["RESULTADO_ANTIGENO"]=df_edomex_["RESULTADO_ANTIGENO"].map(catalogo_resultado_antigeno)
df_edomex_["CLASIFICACION_FINAL"]=df_edomex_["CLASIFICACION_FINAL"].map(catalogo_clasificacion_final)
df_edomex_["MIGRANTE"]=df_edomex_["MIGRANTE"].map(catalogo_si_no)
df_edomex_["UCI"]=df_edomex_["UCI"].map(catalogo_si_no)

# %%
df_edomex_.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN   SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      z2eace           USMER  ESTATAL            MÉXICO
# 1          2022-03-05      z579ac           USMER      SSA            MÉXICO
# 2          2022-03-05      z4e838           USMER      SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z1b053  FUERA DE USMER      SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z454b5           USMER   ISSSTE            MÉXICO
# 5          2022-03-05      z39e04           USMER      SSA            MÉXICO
# 6          2022-03-05      z58ebe           USMER  PRIVADA  CIUDAD DE MÉXICO
# 7          2022-03-05      z39c9e           USMER      SSA            MÉXICO
# 8          2022-03-05      z4e4e4           USMER   ISSSTE            MÉXICO
# 9          2022-03-05      01c25f           USMER      SSA           MORELOS
#
#      SEXO       ENTIDAD_NAC ENTIDAD_RES        MUNICIPIO_RES  TIPO_PACIENTE  \
# ...

# %%
"""Como vamos a trabajar ya solo con eso df eliminamos los otros"""
df_cdmx=df_cdmx_

# %%
df_cdmx.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 5          2022-03-05      z526b3  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 6          2022-03-05      z3d1e2  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 7          2022-03-05      z29dac  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 8          2022-03-05      z45dcb  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 9          2022-03-05      z23c2e  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# ...

# %%
del(df_cdmx_)

# %%
df_edomex=df_edomex_

# %%
df_edomex.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN   SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      z2eace           USMER  ESTATAL            MÉXICO
# 1          2022-03-05      z579ac           USMER      SSA            MÉXICO
# 2          2022-03-05      z4e838           USMER      SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z1b053  FUERA DE USMER      SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z454b5           USMER   ISSSTE            MÉXICO
# 5          2022-03-05      z39e04           USMER      SSA            MÉXICO
# 6          2022-03-05      z58ebe           USMER  PRIVADA  CIUDAD DE MÉXICO
# 7          2022-03-05      z39c9e           USMER      SSA            MÉXICO
# 8          2022-03-05      z4e4e4           USMER   ISSSTE            MÉXICO
# 9          2022-03-05      01c25f           USMER      SSA           MORELOS
#
#      SEXO       ENTIDAD_NAC ENTIDAD_RES        MUNICIPIO_RES  TIPO_PACIENTE  \
# ...

# %%
del(df_edomex_)

# %%
del(df_covid)

# %%
"""Exportamos la data"""
df_cdmx.to_csv(path+"/COVIDCDMX_MAPEADO.csv",index=False,encoding="utf-8")
df_edomex.to_csv(path+"/COVIDEDOMEX_MAPEADO.csv",index=False,encoding="utf-8")

# %%
"""Para la construccion de la TAD juntemos ambos csv"""

df_mexico = df_cdmx.append(df_edomex,ignore_index=True)
df_mexico.shape[0]
# Out:
# /var/folders/m5/cfc15px573ld6bgr5zly12_m0000gn/T/ipykernel_3173/2861927825.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mexico = df_cdmx.append(df_edomex,ignore_index=True)
# 6458251

# %%
df_cdmx.shape[0]+df_edomex.shape[0]
# Out:
# 6458251

# %%
df_mexico.tail(10)
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR ENTIDAD_UM  \
# 6458241          2022-03-05     m0d24cb  FUERA DE USMER    SSA     MÉXICO
# 6458242          2022-03-05     m0baf85  FUERA DE USMER    SSA     MÉXICO
# 6458243          2022-03-05     m06a012  FUERA DE USMER    SSA     MÉXICO
# 6458244          2022-03-05     m04925e  FUERA DE USMER    SSA     MÉXICO
# 6458245          2022-03-05     m133a18  FUERA DE USMER    SSA     MÉXICO
# 6458246          2022-03-05     m011a9c  FUERA DE USMER    SSA     MÉXICO
# 6458247          2022-03-05     m062edc  FUERA DE USMER    SSA     MÉXICO
# 6458248          2022-03-05     m093b3f  FUERA DE USMER    SSA     MÉXICO
# 6458249          2022-03-05     m120a01  FUERA DE USMER    SSA     MÉXICO
# 6458250          2022-03-05     m156b47  FUERA DE USMER    SSA     MÉXICO
#
#            SEXO       ENTIDAD_NAC ENTIDAD_RES            MUNICIPIO_RES  \
# 6458241   MUJER            MÉXICO      MÉXICO      TLALNEPANTLA DE BAZ
# ...

# %% [markdown]
# ## Construccion de la TAD
#
# 1.- Unidad Muestral: Municipios

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Vamos a usar el municipio de residencia como unidad muestral para la TAD"""
df_tad = pd.DataFrame()
df_tad["Municipio"]=list(df_mexico["MUNICIPIO_RES"].unique())

# %%
df_tad
# Out:
#                  Municipio
# 0               IZTAPALAPA
# 1      VENUSTIANO CARRANZA
# 2    CUAJIMALPA DE MORELOS
# 3             AZCAPOTZALCO
# 4                  TLALPAN
# ..                     ...
# 138             POLOTITLÁN
# 139               TONATICO
# 140              ZACUALPAN
# 141            TEXCALYACAC
# 142             OTZOLOAPAN
#
# [143 rows x 1 columns]

# %%
entidad=df_mexico[["MUNICIPIO_RES","ENTIDAD_RES"]]
entidad=entidad.drop_duplicates(subset=["MUNICIPIO_RES"])
entidad = entidad.reset_index(drop=True)
entidad
# Out:
#              MUNICIPIO_RES       ENTIDAD_RES
# 0               IZTAPALAPA  CIUDAD DE MÉXICO
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO
# 4                  TLALPAN  CIUDAD DE MÉXICO
# ..                     ...               ...
# 138             POLOTITLÁN            MÉXICO
# 139               TONATICO            MÉXICO
# 140              ZACUALPAN            MÉXICO
# 141            TEXCALYACAC            MÉXICO
# 142             OTZOLOAPAN            MÉXICO
#
# [143 rows x 2 columns]

# %%
df_tad = df_tad.merge(entidad, how = 'left', left_on = 'Municipio', right_on = 'MUNICIPIO_RES')
df_tad
# Out:
#                  Municipio          MUNICIPIO_RES       ENTIDAD_RES
# 0               IZTAPALAPA             IZTAPALAPA  CIUDAD DE MÉXICO
# 1      VENUSTIANO CARRANZA    VENUSTIANO CARRANZA  CIUDAD DE MÉXICO
# 2    CUAJIMALPA DE MORELOS  CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO
# 3             AZCAPOTZALCO           AZCAPOTZALCO  CIUDAD DE MÉXICO
# 4                  TLALPAN                TLALPAN  CIUDAD DE MÉXICO
# ..                     ...                    ...               ...
# 138             POLOTITLÁN             POLOTITLÁN            MÉXICO
# 139               TONATICO               TONATICO            MÉXICO
# 140              ZACUALPAN              ZACUALPAN            MÉXICO
# 141            TEXCALYACAC            TEXCALYACAC            MÉXICO
# 142             OTZOLOAPAN             OTZOLOAPAN            MÉXICO
#
# [143 rows x 3 columns]

# %%
df_tad=df_tad[["Municipio","ENTIDAD_RES"]]
df_tad
# Out:
#                  Municipio       ENTIDAD_RES
# 0               IZTAPALAPA  CIUDAD DE MÉXICO
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO
# 4                  TLALPAN  CIUDAD DE MÉXICO
# ..                     ...               ...
# 138             POLOTITLÁN            MÉXICO
# 139               TONATICO            MÉXICO
# 140              ZACUALPAN            MÉXICO
# 141            TEXCALYACAC            MÉXICO
# 142             OTZOLOAPAN            MÉXICO
#
# [143 rows x 2 columns]

# %%
df_tad=df_tad.rename(columns={"ENTIDAD_RES":"Entidad"})
df_tad
# Out:
#                  Municipio           Entidad
# 0               IZTAPALAPA  CIUDAD DE MÉXICO
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO
# 4                  TLALPAN  CIUDAD DE MÉXICO
# ..                     ...               ...
# 138             POLOTITLÁN            MÉXICO
# 139               TONATICO            MÉXICO
# 140              ZACUALPAN            MÉXICO
# 141            TEXCALYACAC            MÉXICO
# 142             OTZOLOAPAN            MÉXICO
#
# [143 rows x 2 columns]

# %%
del(entidad)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Eliminemos datos con id repetidos"""
print(df_mexico.shape[0])
df_mexico=df_mexico.drop_duplicates(subset=['ID_REGISTRO'])
df_mexico.shape[0]
# Out:
# 6458251
# 6458251

# %%
"""No hay registros repetidos ahora veamos que no haya nulos"""
df_mexico["ID_REGISTRO"].isnull().values.any()
# Out:
# False

# %%
"""Como no hay valores si registros calcules los contagiados, a ver cuantos hubo"""
aux1=df_mexico[["MUNICIPIO_RES","ID_REGISTRO"]].groupby("MUNICIPIO_RES").count()
aux1.columns=["Total de Registros"]
aux1.head(3)
# Out:
#                            Total de Registros
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                3091
# ACOLMAN                                  8166
# ACULCO                                   1633

# %%
df_tad=df_tad.merge(aux1,how="left",left_on="Municipio",right_index=True)
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
# [143 rows x 3 columns]

# %%
del(aux1)

# %%
"""Veamos el total de contagiados"""
aux_2=df_mexico[["MUNICIPIO_RES","CLASIFICACION_FINAL","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="CLASIFICACION_FINAL",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux_2
# Out:
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                 54
# ACOLMAN                                                                  128
# ACULCO                                                                     9
# ALMOLOYA DE ALQUISIRAS                                                     3
# ALMOLOYA DE JUÁREZ                                                        54
# ...                                                                      ...
# ZACUALPAN                                                                  3
# ZINACANTEPEC                                                              61
# ZUMPAHUACÁN                                                                1
# ZUMPANGO                                                                 166
# ÁLVARO OBREGÓN                                                         75981
#
# ...

# %%
aux_2.columns=[x.capitalize() for x in aux_2.columns]

# %%
aux_2.head()
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                 54
# ACOLMAN                                                                  128
# ACULCO                                                                     9
# ALMOLOYA DE ALQUISIRAS                                                     3
# ALMOLOYA DE JUÁREZ                                                        54
#
#                            Caso de covid-19 confirmado por comité de  dictaminación  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  2
# ACOLMAN                                                                   11
# ACULCO                                                                     2
# ALMOLOYA DE ALQUISIRAS                                                     1
# ...

# %%
aux_2.columns
# Out:
# Index(['Caso de covid-19 confirmado por asociación clínica epidemiológica',
#        'Caso de covid-19 confirmado por comité de  dictaminación',
#        'Caso de sars-cov-2  confirmado', 'Caso sospechoso',
#        'Inválido por laboratorio', 'Negativo a sars-cov-2',
#        'No realizado por laboratorio'],
#       dtype='object')

# %%
aux_2["Total de casos confirmados"]= aux_2["Caso de covid-19 confirmado por asociación clínica epidemiológica"]+aux_2["Caso de covid-19 confirmado por comité de  dictaminación"]+aux_2["Caso de sars-cov-2  confirmado"]

# %%
aux_2
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                 54
# ACOLMAN                                                                  128
# ACULCO                                                                     9
# ALMOLOYA DE ALQUISIRAS                                                     3
# ALMOLOYA DE JUÁREZ                                                        54
# ...                                                                      ...
# ZACUALPAN                                                                  3
# ZINACANTEPEC                                                              61
# ZUMPAHUACÁN                                                                1
# ZUMPANGO                                                                 166
# ÁLVARO OBREGÓN                                                         75981
#
# ...

# %%
df_tad=df_tad.merge(aux_2,how="left",left_on="Municipio",right_index=True)
df_tad.head(5)
# Out:
#                Municipio           Entidad  Total de Registros  \
# 0             IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1    VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2  CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3           AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                TLALPAN  CIUDAD DE MÉXICO            362166.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
# 1                                             3274.0
# 2                                             2202.0
# 3                                             7218.0
# 4                                            36375.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
# 1                                              230.0
# 2                                               46.0
# ...

# %%
del(aux_2)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Veamos número de personas que necesitaron ingresar a una Unidad de Cuidados Intensivos"""
aux1=df_mexico[["MUNICIPIO_RES","UCI","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="UCI",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux1
# Out:
# UCI                          NO   NO APLICA  NO ESPECIFICADO  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA    468       2592                2   29
# ACOLMAN                      757       7364                4   41
# ACULCO                       191       1430                1   11
# ALMOLOYA DE ALQUISIRAS        36        563                0    8
# ALMOLOYA DE JUÁREZ          1065       3338                4   70
# ...                          ...        ...              ...  ...
# ZACUALPAN                     28        263                1    2
# ZINACANTEPEC                1499       5841                5   98
# ZUMPAHUACÁN                  163       1202                3    5
# ZUMPANGO                    2166      12597                6   96
# ÁLVARO OBREGÓN             13034     460110               64  873
#
# [142 rows x 4 columns]

# %%
aux1.columns = [c.capitalize() for c in aux1.columns]
aux1.head(3)
# Out:
#                            No   No aplica  No especificado  Si
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  468       2592                2   29
# ACOLMAN                    757       7364                4   41
# ACULCO                     191       1430                1   11

# %%
df_tad=df_tad.merge(aux1,how="left",left_on="Municipio",right_index=True)

# %%
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
df_tad.columns
# Out:
# Index(['Municipio', 'Entidad', 'Total de Registros',
#        'Caso de covid-19 confirmado por asociación clínica epidemiológica',
#        'Caso de covid-19 confirmado por comité de  dictaminación',
#        'Caso de sars-cov-2  confirmado', 'Caso sospechoso',
#        'Inválido por laboratorio', 'Negativo a sars-cov-2',
#        'No realizado por laboratorio', 'Total de casos confirmados', 'No ',
#        'No aplica', 'No especificado', 'Si '],
#       dtype='object')

# %%
df_tad.rename(columns={'No ':'No UCI',
                        'No aplica':'No aplica UCI',"No especificado":'No especificado UCI','Si ':'Si UCI'},
               inplace=True)

# %%
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
del(aux1)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Calculemos el numero de personas que se realizaron la prueba ya se de laboratorio o antigeno"""
aux1=df_mexico[["MUNICIPIO_RES","TOMA_MUESTRA_LAB","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="TOMA_MUESTRA_LAB",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux1
# Out:
# TOMA_MUESTRA_LAB              NO      SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA    1688    1403
# ACOLMAN                      4462    3704
# ACULCO                       1275     358
# ALMOLOYA DE ALQUISIRAS        294     313
# ALMOLOYA DE JUÁREZ           2324    2153
# ...                           ...     ...
# ZACUALPAN                     115     179
# ZINACANTEPEC                 3747    3696
# ZUMPAHUACÁN                  1149     224
# ZUMPANGO                    10067    4798
# ÁLVARO OBREGÓN             369824  104257
#
# [142 rows x 2 columns]

# %%
aux1.columns=[c.capitalize()+" Toma de muesta lab" for c in aux1.columns]
aux1.head(3)
# Out:
#                            No  Toma de muesta lab  Si  Toma de muesta lab
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    1688                    1403
# ACOLMAN                                      4462                    3704
# ACULCO                                       1275                     358

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
del(aux1)
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Toma de muestra antigeno"""
aux1=df_mexico[["MUNICIPIO_RES","TOMA_MUESTRA_ANTIGENO","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="TOMA_MUESTRA_ANTIGENO",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux1.columns=[c.capitalize()+" Toma de muesta antigeno" for c in aux1.columns]
aux1.head(3)
# Out:
#                            No  Toma de muesta antigeno  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         1439
# ACOLMAN                                           3697
# ACULCO                                             336
#
#                            Si  Toma de muesta antigeno
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         1652
# ACOLMAN                                           4469
# ACULCO                                            1297

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
del(aux1)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Resultado laboratorio"""
aux1=df_mexico[["MUNICIPIO_RES","RESULTADO_LAB","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="RESULTADO_LAB",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux1
# Out:
# RESULTADO_LAB              NO APLICA (CASO SIN MUESTRA)  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          1688
# ACOLMAN                                            4462
# ACULCO                                             1275
# ALMOLOYA DE ALQUISIRAS                              294
# ALMOLOYA DE JUÁREZ                                 2324
# ...                                                 ...
# ZACUALPAN                                           115
# ZINACANTEPEC                                       3747
# ZUMPAHUACÁN                                        1149
# ZUMPANGO                                          10067
# ÁLVARO OBREGÓN                                   369824
#
# RESULTADO_LAB              NO POSITIVO A SARS-COV-2  POSITIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                       802                    448
# ACOLMAN                                        2125                   1250
# ...

# %%
aux1.columns=[c.capitalize()+" Resultado lab" for c in aux1.columns]
aux1.head(3)
# Out:
#                            No aplica (caso sin muestra) Resultado lab  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                        1688
# ACOLMAN                                                          4462
# ACULCO                                                           1275
#
#                            No positivo a sars-cov-2 Resultado lab  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                     802
# ACOLMAN                                                      2125
# ACULCO                                                        213
#
#                            Positivo a sars-cov-2 Resultado lab  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                  448
# ACOLMAN                                                   1250
# ACULCO                                                     114
#
#                            Resultado no adecuado  Resultado lab  \
# MUNICIPIO_RES
# ...

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
del(aux1)
"""Resultado Antigeno"""
aux1=df_mexico[["MUNICIPIO_RES","RESULTADO_ANTIGENO","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="RESULTADO_ANTIGENO",aggfunc="count",fill_value=0,values="ID_REGISTRO")

# %%
aux1
# Out:
# RESULTADO_ANTIGENO         NEGATIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                   1270
# ACOLMAN                                     3379
# ACULCO                                       989
# ALMOLOYA DE ALQUISIRAS                       237
# ALMOLOYA DE JUÁREZ                          1747
# ...                                          ...
# ZACUALPAN                                    100
# ZINACANTEPEC                                2495
# ZUMPAHUACÁN                                 1072
# ZUMPANGO                                    6350
# ÁLVARO OBREGÓN                            303721
#
# RESULTADO_ANTIGENO         NO APLICA (CASO SIN MUESTRA)  POSITIVO A SARS-COV-2
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          1439                    382
# ACOLMAN                                            3697                   1090
# ACULCO                                              336                    308
# ...

# %%
aux1.columns=[c.capitalize()+" Resultado antigeno" for c in aux1.columns]
aux1.head(3)
# Out:
#                            Negativo a sars-cov-2 Resultado antigeno  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                      1270
# ACOLMAN                                                        3379
# ACULCO                                                          989
#
#                            No aplica (caso sin muestra) Resultado antigeno  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                             1439
# ACOLMAN                                                               3697
# ACULCO                                                                 336
#
#                            Positivo a sars-cov-2 Resultado antigeno
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                       382
# ACOLMAN                                                        1090
# ACULCO                                                          308

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad
# Out:
#                  Municipio           Entidad  Total de Registros  \
# 0               IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1      VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2    CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3             AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                  TLALPAN  CIUDAD DE MÉXICO            362166.0
# ..                     ...               ...                 ...
# 138             POLOTITLÁN            MÉXICO               180.0
# 139               TONATICO            MÉXICO               554.0
# 140              ZACUALPAN            MÉXICO               294.0
# 141            TEXCALYACAC            MÉXICO               350.0
# 142             OTZOLOAPAN            MÉXICO               273.0
#
#      Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                              20914.0
# 1                                               3274.0
# ...

# %%
del(aux1)
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Origen de los datos"""
aux1=df_mexico[["MUNICIPIO_RES","ORIGEN","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="ORIGEN",aggfunc="count",fill_value=0,values="ID_REGISTRO")
aux1.head(1)
# Out:
# ORIGEN                     FUERA DE USMER  USMER
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA            2244    847

# %%
aux1.columns=["Origen "+ c.capitalize() for c in aux1.columns]
aux1.head(1)
# Out:
#                            Origen Fuera de usmer  Origen Usmer
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                   2244           847

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    No aplica (caso sin muestra) Resultado lab  \
# 0                                    663870.0
#
#    No positivo a sars-cov-2 Resultado lab  \
# 0                                 95378.0
#
#    Positivo a sars-cov-2 Resultado lab  Resultado no adecuado  Resultado lab  \
# ...

# %%
"""Sector de atención"""
del(aux1)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
aux1=df_mexico[["MUNICIPIO_RES","SECTOR","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="SECTOR",aggfunc="count",fill_value=0,values="ID_REGISTRO")
aux1.head(1)
# Out:
# SECTOR                     CRUZ ROJA  DIF  ESTATAL  IMSS  IMSS-BIENESTAR  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          0    0       55   398               3
#
# SECTOR                     ISSSTE  MUNICIPAL  PEMEX  PRIVADA  SEDENA  SEMAR  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA      45          0      1      122      33      4
#
# SECTOR                      SSA  UNIVERSITARIO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2430              0

# %%
aux1.columns=["Sector at "+ c.capitalize() for c in aux1.columns]
aux1.head(1)
# Out:
#                            Sector at Cruz roja  Sector at Dif  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    0              0
#
#                            Sector at Estatal  Sector at Imss  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                 55             398
#
#                            Sector at Imss-bienestar  Sector at Issste  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         3                45
#
#                            Sector at Municipal  Sector at Pemex  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    0                1
#
#                            Sector at Privada  Sector at Sedena  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                122                33
#
#                            Sector at Semar  Sector at Ssa  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                4           2430
#
#                            Sector at Universitario
# MUNICIPIO_RES
# ...

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Sector at Imss  \
# 0               601317.0                        2975.0  ...        120958.0
#
#    Sector at Imss-bienestar  Sector at Issste  Sector at Municipal  \
# 0                      16.0            6526.0                  0.0
#
#    Sector at Pemex  Sector at Privada  Sector at Sedena  Sector at Semar  \
# 0            815.0            46718.0             916.0           1291.0
#
# ...

# %%
del(aux1)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Sexo paciente"""
aux1=df_mexico[["MUNICIPIO_RES","SEXO","ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns="SEXO",aggfunc="count",fill_value=0,values="ID_REGISTRO")
aux1.head(1)
# Out:
# SEXO                       HOMBRE  MUJER
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA    1642   1449

# %%
aux1.columns=["Paciente "+ c.capitalize() for c in aux1.columns]
aux1.head(1)
# Out:
#                            Paciente Hombre  Paciente Mujer
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA             1642            1449

# %%
df_tad=df_tad.merge(aux1,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Sector at Issste  \
# 0               601317.0                        2975.0  ...            6526.0
#
#    Sector at Municipal  Sector at Pemex  Sector at Privada  Sector at Sedena  \
# 0                  0.0            815.0            46718.0             916.0
#
#    Sector at Semar  Sector at Ssa  Sector at Universitario  Paciente Hombre  \
# ...

# %%
"""Creacion de funcion para optimizar proceso"""
def tabla_pivote(columna):
    aux1=df_mexico[["MUNICIPIO_RES",columna,"ID_REGISTRO"]].pivot_table(index="MUNICIPIO_RES",columns=columna,aggfunc="count",fill_value=0,values="ID_REGISTRO")
    print(aux1.head(1))
    return aux1

# %%
del(aux1)

# %%
"""Tipo de paciente"""
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
aux = tabla_pivote('TIPO_PACIENTE')
# Out:
# TIPO_PACIENTE              AMBULATORIO  HOSPITALIZADO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA         2592            499

# %%
aux.columns=["Paciente "+ c.capitalize() for c in aux.columns]
aux.head(1)
# Out:
#                            Paciente Ambulatorio  Paciente Hospitalizado
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                  2592                     499

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Sector at Pemex  \
# 0               601317.0                        2975.0  ...            815.0
#
#    Sector at Privada  Sector at Sedena  Sector at Semar  Sector at Ssa  \
# 0            46718.0             916.0           1291.0       643550.0
#
#    Sector at Universitario  Paciente Hombre  Paciente Mujer  \
# 0                      4.0         378485.0        442617.0
#
# ...

# %%
del(aux)

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
"""Intubado"""
aux=tabla_pivote('INTUBADO')
# Out:
# INTUBADO                   NO   NO APLICA  NO ESPECIFICADO  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  457       2592                2   40

# %%
aux.columns=[c.capitalize()+" Intubado" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Intubado  No aplica Intubado  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA           457                2592
#
#                            No especificado Intubado  Si  Intubado
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         2            40

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Sector at Ssa  \
# 0               601317.0                        2975.0  ...       643550.0
#
#    Sector at Universitario  Paciente Hombre  Paciente Mujer  \
# 0                      4.0         378485.0        442617.0
#
#    Paciente Ambulatorio  Paciente Hospitalizado  No  Intubado  \
# 0              791554.0                 29548.0       25159.0
#
# ...

# %%
del(aux)

# %%
"""Neumonia"""
aux=tabla_pivote("NEUMONIA")
# Out:
# NEUMONIA                    NO   NO ESPECIFICADO  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2687              138  266

# %%
aux.columns=[c.capitalize()+" Neumonia" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Neumonia  No especificado Neumonia  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          2687                       138
#
#                            Si  Neumonia
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA           266

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Paciente Mujer  \
# 0               601317.0                        2975.0  ...        442617.0
#
#    Paciente Ambulatorio  Paciente Hospitalizado  No  Intubado  \
# 0              791554.0                 29548.0       25159.0
#
#    No aplica Intubado  No especificado Intubado  Si  Intubado  No  Neumonia  \
# 0            791554.0                     107.0        4282.0      797279.0
#
# ...

# %%
"""Edad paciente promedio"""
aux = df_mexico[["MUNICIPIO_RES","EDAD"]].groupby("MUNICIPIO_RES").agg(["mean","max","min"])

# %%
aux.head(1)
# Out:
#                                EDAD
#                                mean max min
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  36.12779  98   0

# %%
aux.columns=["Edad promedio","Edad maxima","Edad minima"]

# %%
aux.head(1)
# Out:
#                            Edad promedio  Edad maxima  Edad minima
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA       36.12779           98            0

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  No  Intubado  \
# 0               601317.0                        2975.0  ...       25159.0
#
#    No aplica Intubado  No especificado Intubado  Si  Intubado  No  Neumonia  \
# 0            791554.0                     107.0        4282.0      797279.0
#
#    No especificado Neumonia  Si  Neumonia  Edad promedio  Edad maxima  \
# 0                     454.0       23369.0      38.734271        122.0
#
# ...

# %%
"""Diabetes"""
aux = tabla_pivote("DIABETES")
# Out:
# DIABETES                    NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2934          7  150

# %%
aux.columns=[c.capitalize()+" Diabetes" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Diabetes  Se ignora Diabetes  Si  Diabetes
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          2934                   7           150

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Intubado  \
# 0               601317.0                        2975.0  ...        4282.0
#
#    No  Neumonia  No especificado Neumonia  Si  Neumonia  Edad promedio  \
# 0      797279.0                     454.0       23369.0      38.734271
#
#    Edad maxima  Edad minima  No  Diabetes  Se ignora Diabetes  Si  Diabetes
# 0        122.0          0.0      765787.0              1277.0       54038.0
#
# ...

# %%
"""EPOC"""
aux = tabla_pivote("EPOC")
# Out:
# EPOC                        NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  3062          4   25

# %%
aux.columns=[c.capitalize()+" Epoc" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Epoc  Se ignora Epoc  Si  Epoc
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA      3062               4        25

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Neumonia  \
# 0               601317.0                        2975.0  ...       23369.0
#
#    Edad promedio  Edad maxima  Edad minima  No  Diabetes  Se ignora Diabetes  \
# 0      38.734271        122.0          0.0      765787.0              1277.0
#
#    Si  Diabetes  No  Epoc  Se ignora Epoc  Si  Epoc
# 0       54038.0  816478.0          1043.0    3581.0
#
# [1 rows x 62 columns]

# %%
"""ASMA"""
aux = tabla_pivote("ASMA")
# Out:
# ASMA                        NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  3059          3   29

# %%
aux.columns=[c.capitalize()+" Asma" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Asma  Se ignora Asma  Si  Asma
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA      3059               3        29

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Edad minima  \
# 0               601317.0                        2975.0  ...          0.0
#
#    No  Diabetes  Se ignora Diabetes  Si  Diabetes  No  Epoc  Se ignora Epoc  \
# 0      765787.0              1277.0       54038.0  816478.0          1043.0
#
#    Si  Epoc  No  Asma  Se ignora Asma  Si  Asma
# 0    3581.0  808176.0          1020.0   11906.0
#
# [1 rows x 65 columns]

# %%
"""INMUSUPR"""
aux=tabla_pivote("INMUSUPR")
# Out:
# INMUSUPR                    NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  3060          5   26

# %%
aux.columns=[c.capitalize()+" Inmusupr" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Inmusupr  Se ignora Inmusupr  Si  Inmusupr
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          3060                   5            26

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Diabetes  \
# 0               601317.0                        2975.0  ...       54038.0
#
#    No  Epoc  Se ignora Epoc  Si  Epoc  No  Asma  Se ignora Asma  Si  Asma  \
# 0  816478.0          1043.0    3581.0  808176.0          1020.0   11906.0
#
#    No  Inmusupr  Se ignora Inmusupr  Si  Inmusupr
# 0      816612.0              1008.0        3482.0
#
# [1 rows x 68 columns]

# %%
"""HIPERTENSION"""
aux = tabla_pivote("HIPERTENSION")
# Out:
# HIPERTENSION                NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2938          5  148

# %%
aux.columns=[c.capitalize()+" Hipertension" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Hipertension  Se ignora Hipertension  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA              2938                       5
#
#                            Si  Hipertension
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA               148

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Epoc  \
# 0               601317.0                        2975.0  ...    3581.0
#
#    No  Asma  Se ignora Asma  Si  Asma  No  Inmusupr  Se ignora Inmusupr  \
# 0  808176.0          1020.0   11906.0      816612.0              1008.0
#
#    Si  Inmusupr  No  Hipertension  Se ignora Hipertension  Si  Hipertension
# 0        3482.0          750184.0                  1053.0           69865.0
#
# ...

# %%
"""Otras complicaciones"""
aux=tabla_pivote("OTRA_COM")
# Out:
# OTRA_COM                    NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2934        138   19

# %%
aux.columns=[c.capitalize()+" Otras complicaciones" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Otras complicaciones  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                      2934
#
#                            Se ignora Otras complicaciones  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             138
#
#                            Si  Otras complicaciones
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                        19

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Asma  \
# 0               601317.0                        2975.0  ...   11906.0
#
#    No  Inmusupr  Se ignora Inmusupr  Si  Inmusupr  No  Hipertension  \
# 0      816612.0              1008.0        3482.0          750184.0
#
#    Se ignora Hipertension  Si  Hipertension  No  Otras complicaciones  \
# 0                  1053.0           69865.0                  814619.0
#
# ...

# %%
"""CARDIOVASCULAR"""
aux=tabla_pivote("CARDIOVASCULAR")
# Out:
# CARDIOVASCULAR              NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  3071          2   18

# %%
aux.columns=[c.capitalize()+" Cardiovascular" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Cardiovascular  Se ignora Cardiovascular  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                3071                         2
#
#                            Si  Cardiovascular
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                  18

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Inmusupr  \
# 0               601317.0                        2975.0  ...        3482.0
#
#    No  Hipertension  Se ignora Hipertension  Si  Hipertension  \
# 0          750184.0                  1053.0           69865.0
#
#    No  Otras complicaciones  Se ignora Otras complicaciones  \
# 0                  814619.0                          1325.0
#
# ...

# %%
del(aux)

# %%
"""OBESIDAD"""
aux=tabla_pivote("OBESIDAD")
# Out:
# OBESIDAD                    NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2942          2  147

# %%
aux.columns=[c.capitalize()+" Obesidad" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Obesidad  Se ignora Obesidad  Si  Obesidad
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          2942                   2           147

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Hipertension  \
# 0               601317.0                        2975.0  ...           69865.0
#
#    No  Otras complicaciones  Se ignora Otras complicaciones  \
# 0                  814619.0                          1325.0
#
#    Si  Otras complicaciones  No  Cardiovascular  Se ignora Cardiovascular  \
# 0                    5158.0            814541.0                    1007.0
#
# ...

# %%
"""RENAL_CRONICA"""
aux = tabla_pivote("RENAL_CRONICA")
# Out:
# RENAL_CRONICA               NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  3061          2   28

# %%
aux.columns=[c.capitalize()+" Renal cronica" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Renal cronica  Se ignora Renal cronica  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA               3061                        2
#
#                            Si  Renal cronica
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                 28

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Si  Otras complicaciones  No  Cardiovascular  Se ignora Cardiovascular  \
# 0                    5158.0            814541.0                    1007.0
#
#    Si  Cardiovascular  No  Obesidad  Se ignora Obesidad  Si  Obesidad  \
# 0              5554.0      771702.0              1006.0       48394.0
#
# ...

# %%
"""TABAQUISMO"""
aux=tabla_pivote("TABAQUISMO")
# Out:
# TABAQUISMO                  NO   SE IGNORA  SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  2977          6  108

# %%
aux.columns=[c.capitalize()+" Tabaquismo" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Tabaquismo  Se ignora Tabaquismo  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA            2977                     6
#
#                            Si  Tabaquismo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA             108

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Si  Cardiovascular  No  Obesidad  Se ignora Obesidad  Si  Obesidad  \
# 0              5554.0      771702.0              1006.0       48394.0
#
#    No  Renal cronica  Se ignora Renal cronica  Si  Renal cronica  \
# 0           815205.0                    999.0             4898.0
#
# ...

# %%
"""Contacto con otro caso"""
aux = tabla_pivote("OTRO_CASO")
# Out:
# OTRO_CASO                   NO   NO ESPECIFICADO   SI
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA  1752              181  1158

# %%
aux.columns=[c.capitalize()+" Contacto otro caso" for c in aux.columns]
aux.head(1)
# Out:
#                            No  Contacto otro caso  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    1752
#
#                            No especificado Contacto otro caso  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                 181
#
#                            Si  Contacto otro caso
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    1158

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Si  Obesidad  \
# 0               601317.0                        2975.0  ...       48394.0
#
#    No  Renal cronica  Se ignora Renal cronica  Si  Renal cronica  \
# 0           815205.0                    999.0             4898.0
#
#    No  Tabaquismo  Se ignora Tabaquismo  Si  Tabaquismo  \
# 0        754831.0                1045.0         65226.0
#
# ...

# %%
df_mexico["FECHA_DEF"].value_counts(dropna=False)
# Out:
# 9999-99-99    6342243
# 2021-01-20        579
# 2021-01-19        578
# 2021-01-26        568
# 2021-01-25        564
#                ...
# 2020-02-24          1
# 2020-01-11          1
# 2020-02-07          1
# 2020-01-02          1
# 2020-03-20          1
# Name: FECHA_DEF, Length: 781, dtype: int64

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %%
df_mexico["FECHA_DEF"].value_counts(dropna=False).index
# Out:
# Index(['9999-99-99', '2021-01-20', '2021-01-19', '2021-01-26', '2021-01-25',
#        '2021-01-12', '2021-01-17', '2021-01-21', '2021-01-11', '2021-01-22',
#        ...
#        '2020-03-06', '2020-03-24', '2020-02-11', '2020-02-04', '2020-02-27',
#        '2020-02-24', '2020-01-11', '2020-02-07', '2020-01-02', '2020-03-20'],
#       dtype='object', length=781)

# %%
dic_muertos = dict()
for a in list(df_mexico["FECHA_DEF"].value_counts(dropna=False).index):
    if a == "9999-99-99":
        dic_muertos[a]="Vivo"
    else:
        dic_muertos[a]="Muerto"
dic_muertos
# Out:
# {'9999-99-99': 'Vivo',
#  '2021-01-20': 'Muerto',
#  '2021-01-19': 'Muerto',
#  '2021-01-26': 'Muerto',
#  '2021-01-25': 'Muerto',
#  '2021-01-12': 'Muerto',
#  '2021-01-17': 'Muerto',
#  '2021-01-21': 'Muerto',
#  '2021-01-11': 'Muerto',
#  '2021-01-22': 'Muerto',
#  '2021-01-23': 'Muerto',
#  '2021-01-24': 'Muerto',
#  '2021-01-16': 'Muerto',
#  '2021-01-18': 'Muerto',
#  '2021-01-05': 'Muerto',
#  '2021-01-15': 'Muerto',
#  '2021-01-13': 'Muerto',
#  '2021-01-14': 'Muerto',
#  '2021-01-08': 'Muerto',
#  '2021-01-10': 'Muerto',
#  '2021-01-04': 'Muerto',
#  '2021-02-01': 'Muerto',
#  '2021-01-31': 'Muerto',
#  '2021-01-03': 'Muerto',
#  '2021-01-06': 'Muerto',
#  '2021-01-29': 'Muerto',
#  '2021-01-02': 'Muerto',
#  '2021-01-28': 'Muerto',
#  '2021-01-27': 'Muerto',
#  '2021-01-09': 'Muerto',
#  '2021-02-03': 'Muerto',
#  '2021-01-30': 'Muerto',
#  '2020-12-29': 'Muerto',
#  '2020-12-30': 'Muerto',
#  '2021-01-07': 'Muerto',
#  '2021-02-02': 'Muerto',
#  '2020-12-28': 'Muerto',
# ...

# %%
df_mexico["Estado"]=df_mexico["FECHA_DEF"].map(dic_muertos)

# %%
df_mexico.loc[df_mexico["FECHA_DEF"]=='9999-99-99']
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR  \
# 0                2022-03-05      zz7067           USMER    SSA
# 1                2022-03-05      z393a3           USMER    SSA
# 2                2022-03-05      z12d63  FUERA DE USMER    SSA
# 3                2022-03-05      z13788           USMER    SSA
# 4                2022-03-05      z2b144  FUERA DE USMER    SSA
# ...                     ...         ...             ...    ...
# 6458246          2022-03-05     m011a9c  FUERA DE USMER    SSA
# 6458247          2022-03-05     m062edc  FUERA DE USMER    SSA
# 6458248          2022-03-05     m093b3f  FUERA DE USMER    SSA
# 6458249          2022-03-05     m120a01  FUERA DE USMER    SSA
# 6458250          2022-03-05     m156b47  FUERA DE USMER    SSA
#
#                ENTIDAD_UM    SEXO       ENTIDAD_NAC       ENTIDAD_RES  \
# 0        CIUDAD DE MÉXICO  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO
# ...

# %%
"""Vivos y muerto"""
aux= tabla_pivote("Estado")
# Out:
# Estado                     Muerto  Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA     106  2985

# %%
aux.columns=["Estado "+ c.capitalize() for c in aux.columns]
aux.head(1)
# Out:
#                            Estado Muerto  Estado Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA            106         2985

# %%
df_tad=df_tad.merge(aux,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Se ignora Renal cronica  Si  Renal cronica  No  Tabaquismo  \
# 0                    999.0             4898.0        754831.0
#
#    Se ignora Tabaquismo  Si  Tabaquismo  No  Contacto otro caso  \
# 0                1045.0         65226.0                414791.0
#
# ...

# %%
"""Tasa de mortalidad"""
df_tad["Tasa de mortalidad"]=df_tad["Estado Muerto"]/df_tad["Total de Registros"]

# %%
df_tad.head(10)
# Out:
#                Municipio           Entidad  Total de Registros  \
# 0             IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
# 1    VENUSTIANO CARRANZA  CIUDAD DE MÉXICO            289492.0
# 2  CUAJIMALPA DE MORELOS  CIUDAD DE MÉXICO            100476.0
# 3           AZCAPOTZALCO  CIUDAD DE MÉXICO            219490.0
# 4                TLALPAN  CIUDAD DE MÉXICO            362166.0
# 5      GUSTAVO A. MADERO  CIUDAD DE MÉXICO            611406.0
# 6         ÁLVARO OBREGÓN  CIUDAD DE MÉXICO            474081.0
# 7               COYOACÁN  CIUDAD DE MÉXICO            303650.0
# 8                TLÁHUAC  CIUDAD DE MÉXICO            237553.0
# 9             CUAUHTÉMOC  CIUDAD DE MÉXICO            305140.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
# 1                                             3274.0
# 2                                             2202.0
# ...

# %%
"""Guardamos la TAD"""
#df_tad.to_csv(path+"/TAD_COVID19.csv",index=False, encoding="utf-8")
# Out:
# 'Guardamos la TAD'

# %%
df_mexico.to_csv(path+"/COVID_METROPOLI.csv",index=False, encoding="utf-8")

# %%
df_tad["Municipio"].unique()
# Out:
# array(['IZTAPALAPA', 'VENUSTIANO CARRANZA', 'CUAJIMALPA DE MORELOS',
#        'AZCAPOTZALCO', 'TLALPAN', 'GUSTAVO A. MADERO', 'ÁLVARO OBREGÓN',
#        'COYOACÁN', 'TLÁHUAC', 'CUAUHTÉMOC', 'IZTACALCO', 'XOCHIMILCO',
#        'BENITO JUÁREZ', 'LA MAGDALENA CONTRERAS', 'MIGUEL HIDALGO',
#        'MILPA ALTA', 'NO ESPECIFICADO', nan, 'TOLUCA', 'NICOLÁS ROMERO',
#        'TEPOTZOTLÁN', 'ECATEPEC DE MORELOS', 'TLALNEPANTLA DE BAZ',
#        'NAUCALPAN DE JUÁREZ', 'TULTITLÁN', 'ACULCO', 'AMANALCO',
#        'NEZAHUALCÓYOTL', 'CHIMALHUACÁN', 'SAN MATEO ATENCO', 'LA PAZ',
#        'JILOTZINGO', 'TECÁMAC', 'ZUMPANGO', 'HUEHUETOCA', 'METEPEC',
#        'CHALCO', 'LERMA', 'ATIZAPÁN DE ZARAGOZA', 'CHICOLOAPAN',
#        'ATIZAPÁN', 'HUIXQUILUCAN', 'CUAUTITLÁN',
#        'VALLE DE CHALCO SOLIDARIDAD', 'CUAUTITLÁN IZCALLI', 'IXTLAHUACA',
#        'CALIMAYA', 'TEXCOCO', 'COYOTEPEC', 'COACALCO DE BERRIOZÁBAL',
#        'IXTAPALUCA', 'TENANCINGO', 'TENANGO DEL VALLE',
# ...

# %%
df_tad.shape[0]
# Out:
# 143

# %%
df_tad = df_tad[df_tad['Municipio'].notna()]

# %%
df_tad.shape[0]
# Out:
# 142

# %%
#df_tad.to_csv(path+"/TAD_COVID19.csv",index=False, encoding="utf-8")

# %% [markdown]
# ## Analisis Casos Ultimo 4 meses (nov-2021 a febrero-2022)
# * Poner numero de contagiados, numero de hospitalizados y numero de muertos

# %%
"""Cracion de la separación por fecha de sintomas"""

df_mexico.head(5)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# 1   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 2  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 3   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  CUAJIMALPA DE MORELOS
# 4   MUJER            MÉXICO  CIUDAD DE MÉXICO           AZCAPOTZALCO
#
#   TIPO_PACIENTE  ... TOMA_MUESTRA_LAB                 RESULTADO_LAB  \
# ...

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI', 'Estado'],
#       dtype='object')

# %%
del(aux)

# %%
df_mexico["FECHA_SINTOMAS"][0]
# Out:
# '2020-08-17'

# %%
fechas = list(df_mexico["FECHA_SINTOMAS"].unique())

# %%
fechas.sort()

# %%
fechas
# Out:
# ['2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
# ...

# %%
""" No hay datos raros en estas fechas"""
#Separacion por año
df_mexico["Año Sintomas"]=df_mexico["FECHA_SINTOMAS"].map(lambda x: x.strip().split("-")[0])

# %%
df_mexico.head(5)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# 1   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 2  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 3   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  CUAJIMALPA DE MORELOS
# 4   MUJER            MÉXICO  CIUDAD DE MÉXICO           AZCAPOTZALCO
#
#   TIPO_PACIENTE  ...                 RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# ...

# %%
df_mexico["Mes Sintomas"] = df_mexico["FECHA_SINTOMAS"].map(lambda x: x.strip().split("-")[1])

# %%
df_mexico.head(5)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# 1   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 2  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 3   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  CUAJIMALPA DE MORELOS
# 4   MUJER            MÉXICO  CIUDAD DE MÉXICO           AZCAPOTZALCO
#
#   TIPO_PACIENTE  ... TOMA_MUESTRA_ANTIGENO            RESULTADO_ANTIGENO  \
# ...

# %%
aux_4meses=df_mexico.loc[((df_mexico["Año Sintomas"]=="2021") & (df_mexico["Mes Sintomas"]=="11"))|
                        ((df_mexico["Año Sintomas"]=="2021") & (df_mexico["Mes Sintomas"]=="12"))|
                        ((df_mexico["Año Sintomas"]=="2022") & (df_mexico["Mes Sintomas"]=="01"))|
                        ((df_mexico["Año Sintomas"]=="2022") & (df_mexico["Mes Sintomas"]=="02"))]

# %%
aux_4meses["Año Sintomas"].unique()
# Out:
# array(['2022', '2021'], dtype=object)

# %%
aux_4meses["Mes Sintomas"].unique()
# Out:
# array(['01', '12', '11', '02'], dtype=object)

# %%
aux_4meses.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI', 'Estado',
#        'Año Sintomas', 'Mes Sintomas'],
#       dtype='object')

# %%
"""Conteo de casos positivos noviembre 2021"""
aux_noviembre = aux_4meses.loc[aux_4meses["Mes Sintomas"]=="11"]
contagiados_noviembre = aux_noviembre[["MUNICIPIO_RES","CLASIFICACION_FINAL","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="CLASIFICACION_FINAL",aggfunc="count",fill_value=0,values="ID_REGISTRO")
contagiados_noviembre.head(1)
# Out:
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE SARS-COV-2  CONFIRMADO  CASO SOSPECHOSO  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                               7               71
#
# CLASIFICACION_FINAL        INVÁLIDO POR LABORATORIO  NEGATIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         0                     59
#
# CLASIFICACION_FINAL        NO REALIZADO POR LABORATORIO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             0

# %%
contagiados_noviembre.columns=[c.capitalize()+" Noviembre 2021" for c in contagiados_noviembre.columns]
contagiados_noviembre.head(1)
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de covid-19 confirmado por comité de  dictaminación Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de sars-cov-2  confirmado Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                              7
#
#                            Caso sospechoso Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                              71
#
#                            Inválido por laboratorio Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                        0
#
#                            Negativo a sars-cov-2 Noviembre 2021  \
# MUNICIPIO_RES
# ...

# %%
df_tad=df_tad.merge(contagiados_noviembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Estado Muerto  \
# 0               601317.0                        2975.0  ...        10867.0
#
#    Estado Vivo  Tasa de mortalidad  \
# 0     810235.0            0.013235
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Noviembre 2021  \
# 0                                                429
#
#    Caso de covid-19 confirmado por comité de  dictaminación Noviembre 2021  \
# ...

# %%
del(contagiados_noviembre)

# %%
"""Tipo Paciente noviebre 2021"""
pacientes_noviembre = aux_noviembre[["MUNICIPIO_RES","TIPO_PACIENTE","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="TIPO_PACIENTE",aggfunc="count",fill_value=0,values="ID_REGISTRO")
pacientes_noviembre.head(1)
# Out:
# TIPO_PACIENTE              AMBULATORIO  HOSPITALIZADO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA           59             78

# %%
pacientes_noviembre.columns=[c.capitalize()+" Noviembre 2021" for c in pacientes_noviembre.columns]
pacientes_noviembre.head(1)
# Out:
#                            Ambulatorio Noviembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          59
#
#                            Hospitalizado Noviembre 2021
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                            78

# %%
df_tad=df_tad.merge(pacientes_noviembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Tasa de mortalidad  \
# 0            0.013235
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Noviembre 2021  \
# 0                                                429
#
#    Caso de covid-19 confirmado por comité de  dictaminación Noviembre 2021  \
# 0                                                  0
#
# ...

# %%
del(pacientes_noviembre)

# %%
"""Muertos noviembre 2021"""
muertos_noviembre = aux_noviembre[["MUNICIPIO_RES","Estado","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="Estado",aggfunc="count",fill_value=0,values="ID_REGISTRO")
muertos_noviembre.head(1)
# Out:
# Estado                     Muerto  Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA       0   137

# %%
muertos_noviembre.columns=[c.capitalize()+" Noviembre 2021" for c in muertos_noviembre.columns]
muertos_noviembre.head(1)
# Out:
#                            Muerto Noviembre 2021  Vivo Noviembre 2021
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                      0                  137

# %%
df_tad=df_tad.merge(muertos_noviembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Caso de covid-19 confirmado por comité de  dictaminación Noviembre 2021  \
# 0                                                  0
#
#    Caso de sars-cov-2  confirmado Noviembre 2021  \
# 0                                           1059
#
#    Caso sospechoso Noviembre 2021  Inválido por laboratorio Noviembre 2021  \
# ...

# %%
del(muertos_noviembre)
del(aux_noviembre)

# %%
"""Conteo de casos positivos diciembre 2021"""
aux_diciembre = aux_4meses.loc[aux_4meses["Mes Sintomas"]=="12"]
contagiados_diciembre = aux_diciembre[["MUNICIPIO_RES","CLASIFICACION_FINAL","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="CLASIFICACION_FINAL",aggfunc="count",fill_value=0,values="ID_REGISTRO")
contagiados_diciembre.head(1)
# Out:
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE SARS-COV-2  CONFIRMADO  CASO SOSPECHOSO  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                               3                4
#
# CLASIFICACION_FINAL        INVÁLIDO POR LABORATORIO  NEGATIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         0                     36
#
# CLASIFICACION_FINAL        NO REALIZADO POR LABORATORIO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             0

# %%
contagiados_diciembre.columns=[c.capitalize()+" Diciembre 2021" for c in contagiados_diciembre.columns]
contagiados_diciembre.head(1)
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de covid-19 confirmado por comité de  dictaminación Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de sars-cov-2  confirmado Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                              3
#
#                            Caso sospechoso Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                               4
#
#                            Inválido por laboratorio Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                        0
#
#                            Negativo a sars-cov-2 Diciembre 2021  \
# MUNICIPIO_RES
# ...

# %%
df_tad=df_tad.merge(contagiados_diciembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Hospitalizado Noviembre 2021  Muerto Noviembre 2021  Vivo Noviembre 2021  \
# 0                           637                     56                21962
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Diciembre 2021  \
# 0                                                296
#
# ...

# %%
del(contagiados_diciembre)

# %%
"""Tipo Paciente diciembre 2021"""
pacientes_diciembre = aux_diciembre[["MUNICIPIO_RES","TIPO_PACIENTE","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="TIPO_PACIENTE",aggfunc="count",fill_value=0,values="ID_REGISTRO")
pacientes_diciembre.head(1)
# Out:
# TIPO_PACIENTE              AMBULATORIO  HOSPITALIZADO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA           38              5

# %%
pacientes_diciembre.columns=[c.capitalize()+" Diciembre 2021" for c in pacientes_diciembre.columns]
pacientes_diciembre.head(1)
# Out:
#                            Ambulatorio Diciembre 2021  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          38
#
#                            Hospitalizado Diciembre 2021
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             5

# %%
df_tad=df_tad.merge(pacientes_diciembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Vivo Noviembre 2021  \
# 0                21962
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Diciembre 2021  \
# 0                                                296
#
#    Caso de covid-19 confirmado por comité de  dictaminación Diciembre 2021  \
# 0                                                  0
#
# ...

# %%
"""Muertos diciembre 2021"""
muertos_diciembre = aux_diciembre[["MUNICIPIO_RES","Estado","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="Estado",aggfunc="count",fill_value=0,values="ID_REGISTRO")
muertos_diciembre.head(1)
# Out:
# Estado                     Muerto  Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA       2    41

# %%
muertos_diciembre.columns=[c.capitalize()+" Diciembre 2021" for c in muertos_diciembre.columns]
muertos_diciembre.head(1)
# Out:
#                            Muerto Diciembre 2021  Vivo Diciembre 2021
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                      2                   41

# %%
df_tad=df_tad.merge(muertos_diciembre,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Caso de covid-19 confirmado por comité de  dictaminación Diciembre 2021  \
# 0                                                  0
#
#    Caso de sars-cov-2  confirmado Diciembre 2021  \
# 0                                           3048
#
#    Caso sospechoso Diciembre 2021  Inválido por laboratorio Diciembre 2021  \
# ...

# %%
del(pacientes_diciembre)
del(muertos_diciembre)
del(aux_diciembre)

# %%
"""Conteo de casos positivos enero 2022"""
aux_enero = aux_4meses.loc[aux_4meses["Mes Sintomas"]=="01"]
contagiados_enero = aux_enero[["MUNICIPIO_RES","CLASIFICACION_FINAL","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="CLASIFICACION_FINAL",aggfunc="count",fill_value=0,values="ID_REGISTRO")
contagiados_enero.head(1)
# Out:
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  1
#
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE SARS-COV-2  CONFIRMADO  CASO SOSPECHOSO  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             108               12
#
# CLASIFICACION_FINAL        INVÁLIDO POR LABORATORIO  NEGATIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         0                     60
#
# CLASIFICACION_FINAL        NO REALIZADO POR LABORATORIO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             0

# %%
contagiados_enero.columns=[c.capitalize()+" Enero 2022" for c in contagiados_enero.columns]
contagiados_enero.head(1)
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  1
#
#                            Caso de covid-19 confirmado por comité de  dictaminación Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de sars-cov-2  confirmado Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                        108
#
#                            Caso sospechoso Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          12
#
#                            Inválido por laboratorio Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                    0
#
#                            Negativo a sars-cov-2 Enero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                60
#
# ...

# %%
df_tad=df_tad.merge(contagiados_enero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Hospitalizado Diciembre 2021  Muerto Diciembre 2021  Vivo Diciembre 2021  \
# 0                           533                     46                20083
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Enero 2022  \
# 0                                               1269
#
# ...

# %%
"""Tipo Paciente enero 2022"""
pacientes_enero = aux_enero[["MUNICIPIO_RES","TIPO_PACIENTE","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="TIPO_PACIENTE",aggfunc="count",fill_value=0,values="ID_REGISTRO")
pacientes_enero.head(1)
# Out:
# TIPO_PACIENTE              AMBULATORIO  HOSPITALIZADO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA          149             32

# %%
pacientes_enero.columns=[c.capitalize()+" Enero 2022" for c in pacientes_enero.columns]
pacientes_enero.head(1)
# Out:
#                            Ambulatorio Enero 2022  Hospitalizado Enero 2022
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                     149                        32

# %%
del(contagiados_enero)

# %%
df_tad=df_tad.merge(pacientes_enero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Vivo Diciembre 2021  \
# 0                20083
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Enero 2022  \
# 0                                               1269
#
#    Caso de covid-19 confirmado por comité de  dictaminación Enero 2022  \
# 0                                                  2
#
# ...

# %%
del(pacientes_enero)

# %%
"""Muertos enero 2021"""
muertos_enero = aux_enero[["MUNICIPIO_RES","Estado","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="Estado",aggfunc="count",fill_value=0,values="ID_REGISTRO")
muertos_enero.head(1)
# Out:
# Estado                     Muerto  Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA       4   177

# %%
muertos_enero.columns=[c.capitalize()+" Enero 2022" for c in muertos_enero.columns]
muertos_enero.head(1)
# Out:
#                            Muerto Enero 2022  Vivo Enero 2022
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                  4              177

# %%
df_tad=df_tad.merge(muertos_enero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Caso de covid-19 confirmado por comité de  dictaminación Enero 2022  \
# 0                                                  2
#
#    Caso de sars-cov-2  confirmado Enero 2022  Caso sospechoso Enero 2022  \
# 0                                      37852                         840
#
# ...

# %%
del(muertos_enero)

# %%
del(aux_enero)

# %%
"""Conteo de casos positivos febrero 2022"""
aux_febrero = aux_4meses.loc[aux_4meses["Mes Sintomas"]=="02"]
contagiados_febrero = aux_febrero[["MUNICIPIO_RES","CLASIFICACION_FINAL","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="CLASIFICACION_FINAL",aggfunc="count",fill_value=0,values="ID_REGISTRO")
contagiados_febrero.head(1)
# Out:
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  2
#
# CLASIFICACION_FINAL        CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
# CLASIFICACION_FINAL        CASO DE SARS-COV-2  CONFIRMADO  CASO SOSPECHOSO  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                              27               10
#
# CLASIFICACION_FINAL        INVÁLIDO POR LABORATORIO  NEGATIVO A SARS-COV-2  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                         1                     32
#
# CLASIFICACION_FINAL        NO REALIZADO POR LABORATORIO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                             0

# %%
contagiados_febrero.columns=[c.capitalize()+" Febrero 2022" for c in contagiados_febrero.columns]
contagiados_febrero.head(1)
# Out:
#                            Caso de covid-19 confirmado por asociación clínica epidemiológica Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  2
#
#                            Caso de covid-19 confirmado por comité de  dictaminación Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                                  0
#
#                            Caso de sars-cov-2  confirmado Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                           27
#
#                            Caso sospechoso Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                            10
#
#                            Inválido por laboratorio Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                                      1
#
#                            Negativo a sars-cov-2 Febrero 2022  \
# MUNICIPIO_RES
# ...

# %%
df_tad=df_tad.merge(contagiados_febrero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Hospitalizado Enero 2022  Muerto Enero 2022  Vivo Enero 2022  \
# 0                      1241                270            81202
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Febrero 2022  \
# 0                                                268
#
# ...

# %%
del(contagiados_febrero)

# %%
"""Tipo Paciente febrero 2022"""
pacientes_febrero = aux_febrero[["MUNICIPIO_RES","TIPO_PACIENTE","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="TIPO_PACIENTE",aggfunc="count",fill_value=0,values="ID_REGISTRO")
pacientes_febrero.head(1)
# Out:
# TIPO_PACIENTE              AMBULATORIO  HOSPITALIZADO
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA           56             16

# %%
pacientes_febrero.columns=[c.capitalize()+" Febrero 2022" for c in pacientes_febrero.columns]
pacientes_febrero.head(1)
# Out:
#                            Ambulatorio Febrero 2022  \
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                        56
#
#                            Hospitalizado Febrero 2022
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                          16

# %%
df_tad=df_tad.merge(pacientes_febrero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  Vivo Enero 2022  \
# 0               601317.0                        2975.0  ...            81202
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica Febrero 2022  \
# 0                                                268
#
#    Caso de covid-19 confirmado por comité de  dictaminación Febrero 2022  \
# 0                                                  0
#
# ...

# %%
del(pacientes_febrero)

# %%
muertos_febrero = aux_febrero[["MUNICIPIO_RES","Estado","ID_REGISTRO"]].pivot_table(index = "MUNICIPIO_RES",columns="Estado",aggfunc="count",fill_value=0,values="ID_REGISTRO")
muertos_febrero.head(1)
# Out:
# Estado                     Muerto  Vivo
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA       1    71

# %%
muertos_febrero.columns=[c.capitalize()+" Febrero 2022" for c in muertos_febrero.columns]
muertos_febrero.head(1)
# Out:
#                            Muerto Febrero 2022  Vivo Febrero 2022
# MUNICIPIO_RES
# ACAMBAY DE RUÍZ CASTAÑEDA                    1                 71

# %%
df_tad=df_tad.merge(muertos_febrero,how = "left",left_on="Municipio",right_index=True)
df_tad.head(1)
# Out:
#     Municipio           Entidad  Total de Registros  \
# 0  IZTAPALAPA  CIUDAD DE MÉXICO            821102.0
#
#    Caso de covid-19 confirmado por asociación clínica epidemiológica  \
# 0                                            20914.0
#
#    Caso de covid-19 confirmado por comité de  dictaminación  \
# 0                                              617.0
#
#    Caso de sars-cov-2  confirmado  Caso sospechoso  Inválido por laboratorio  \
# 0                        182347.0          12130.0                     802.0
#
#    Negativo a sars-cov-2  No realizado por laboratorio  ...  \
# 0               601317.0                        2975.0  ...
#
#    Caso de covid-19 confirmado por comité de  dictaminación Febrero 2022  \
# 0                                                  0
#
#    Caso de sars-cov-2  confirmado Febrero 2022  Caso sospechoso Febrero 2022  \
# 0                                         5199                           312
#
# ...

# %%
del(muertos_febrero)
del(aux_febrero)

# %%
del(aux_4meses)

# %%
df_tad.to_csv(path+"/TAD_COVID19.csv",index=False, encoding="utf-8")

# %% [markdown]
# ## Serie de tiempo de contagiados

# %%
df_mexico.head(5)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 0          2022-03-05      zz7067           USMER    SSA  CIUDAD DE MÉXICO
# 1          2022-03-05      z393a3           USMER    SSA  CIUDAD DE MÉXICO
# 2          2022-03-05      z12d63  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 3          2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 4          2022-03-05      z2b144  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 0  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
# 1   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 2  HOMBRE  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO    VENUSTIANO CARRANZA
# 3   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  CUAJIMALPA DE MORELOS
# 4   MUJER            MÉXICO  CIUDAD DE MÉXICO           AZCAPOTZALCO
#
#   TIPO_PACIENTE  ... TOMA_MUESTRA_ANTIGENO            RESULTADO_ANTIGENO  \
# ...

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI', 'Estado',
#        'Año Sintomas', 'Mes Sintomas'],
#       dtype='object')

# %%
df_mexico["CLASIFICACION_FINAL"].unique()
# Out:
# array(['NEGATIVO A SARS-COV-2', 'CASO SOSPECHOSO',
#        'CASO DE SARS-COV-2  CONFIRMADO', 'NO REALIZADO POR LABORATORIO',
#        'CASO DE COVID-19 CONFIRMADO POR ASOCIACIÓN CLÍNICA EPIDEMIOLÓGICA',
#        'CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DICTAMINACIÓN',
#        'INVÁLIDO POR LABORATORIO'], dtype=object)

# %%
serie_contagiados = df_mexico.loc[df_mexico["CLASIFICACION_FINAL"]=="CASO DE SARS-COV-2  CONFIRMADO"]

# %%
serie_contagiados.head(5)
# Out:
#    FECHA_ACTUALIZACION ID_REGISTRO          ORIGEN SECTOR        ENTIDAD_UM  \
# 3           2022-03-05      z13788           USMER    SSA  CIUDAD DE MÉXICO
# 5           2022-03-05      z526b3  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 6           2022-03-05      z3d1e2  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
# 13          2022-03-05      z2770b           USMER    SSA  CIUDAD DE MÉXICO
# 43          2022-03-05      3b64a1  FUERA DE USMER    SSA  CIUDAD DE MÉXICO
#
#      SEXO       ENTIDAD_NAC       ENTIDAD_RES          MUNICIPIO_RES  \
# 3   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  CUAJIMALPA DE MORELOS
# 5   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO                TLALPAN
# 6   MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO      GUSTAVO A. MADERO
# 13  MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO              IZTACALCO
# 43  MUJER  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO             IZTAPALAPA
#
#    TIPO_PACIENTE  ... TOMA_MUESTRA_ANTIGENO            RESULTADO_ANTIGENO  \
# ...

# %%
serie_contagiados = serie_contagiados[["ID_REGISTRO","FECHA_SINTOMAS"]]

# %%
serie_contagiados["FECHA_SINTOMAS"] = pd.to_datetime(serie_contagiados["FECHA_SINTOMAS"]).dt.strftime("%Y-%m-%d %H:%M")

# %%
serie_contagiados["Fecha"]=pd.to_datetime(serie_contagiados["FECHA_SINTOMAS"])

# %%
serie_contagiados.dtypes
# Out:
# ID_REGISTRO               object
# FECHA_SINTOMAS            object
# Fecha             datetime64[ns]
# dtype: object

# %%
serie_contagiados = serie_contagiados[["Fecha","ID_REGISTRO"]].groupby("Fecha").count()

# %%
serie_contagiados.head(10)
# Out:
#             ID_REGISTRO
# Fecha
# 2020-02-19            1
# 2020-02-22            1
# 2020-02-23            1
# 2020-02-26            1
# 2020-02-28            2
# 2020-02-29            2
# 2020-03-01            2
# 2020-03-02            6
# 2020-03-03            6
# 2020-03-04            5

# %%
import matplotlib.pyplot as plt 
x=list(serie_contagiados.index)
y=serie_contagiados["ID_REGISTRO"]
plt.plot(x,y, color="blue")
plt.title("Contagios Covid 19 en CDMX y EDOMEX")
plt.gcf().set_size_inches(9, 7)
plt.savefig("Serie contagios.jpg", bbox_inches='tight')
plt.show()

# %%
del(serie_contagiados)

# %% [markdown]
# ## Serie de Tiempo muertes

# %%
df_mexico.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
#        'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
#        'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI', 'Estado',
#        'Año Sintomas', 'Mes Sintomas'],
#       dtype='object')

# %%
df_mexico["Estado"].unique()
# Out:
# array(['Vivo', 'Muerto'], dtype=object)

# %%
serie_muertos = df_mexico.loc[df_mexico["Estado"]=="Muerto"]

# %%
serie_muertos.head(2)
# Out:
#     FECHA_ACTUALIZACION ID_REGISTRO ORIGEN SECTOR        ENTIDAD_UM    SEXO  \
# 64           2022-03-05      2bdb17  USMER   IMSS  CIUDAD DE MÉXICO  HOMBRE
# 204          2022-03-05      279588  USMER   IMSS  CIUDAD DE MÉXICO   MUJER
#
#           ENTIDAD_NAC       ENTIDAD_RES      MUNICIPIO_RES  TIPO_PACIENTE  \
# 64   CIUDAD DE MÉXICO  CIUDAD DE MÉXICO          IZTACALCO  HOSPITALIZADO
# 204  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO  GUSTAVO A. MADERO  HOSPITALIZADO
#
#      ... TOMA_MUESTRA_ANTIGENO            RESULTADO_ANTIGENO  \
# 64   ...                   NO   NO APLICA (CASO SIN MUESTRA)
# 204  ...                   NO   NO APLICA (CASO SIN MUESTRA)
#
#                                    CLASIFICACION_FINAL         MIGRANTE  \
# 64                      CASO DE SARS-COV-2  CONFIRMADO  NO ESPECIFICADO
# 204  CASO DE COVID-19 CONFIRMADO POR COMITÉ DE  DIC...  NO ESPECIFICADO
#
#     PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI  Estado Año Sintomas Mes Sintomas
# ...

# %%
serie_muertos = serie_muertos[["ID_REGISTRO","FECHA_DEF"]]
serie_muertos["FECHA_DEF"] = pd.to_datetime(serie_muertos["FECHA_DEF"]).dt.strftime("%Y-%m-%d %H:%M")
serie_muertos["Fecha"]=pd.to_datetime(serie_muertos["FECHA_DEF"])

# %%
serie_muertos=serie_muertos[["ID_REGISTRO","Fecha"]].groupby("Fecha").count()

# %%
serie_muertos.head(10)
# Out:
#             ID_REGISTRO
# Fecha
# 2020-01-02            1
# 2020-01-07            2
# 2020-01-08            1
# 2020-01-09            2
# 2020-01-10            5
# 2020-01-11            1
# 2020-01-12            1
# 2020-01-13            1
# 2020-01-14            2
# 2020-01-15            2

# %%
x=list(serie_muertos.index)
y=serie_muertos["ID_REGISTRO"]
plt.plot(x,y, color="red")
plt.title("Muertes por Covid 19 en CDMX y EDOMEX")
plt.gcf().set_size_inches(9, 7)
plt.savefig("Serie muertes.jpg", bbox_inches='tight')
plt.show()
